# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://piste.gouv.fr/images/logo-Piste-large.png" alt="Logo Piste" width="400" />
# </div>

# %% [markdown]
# # I. Présentation de l'API LégiFrance :
#
# Au total : ~70 requêtes API classées en 6 grandes familles.

# %% [markdown]
# ### Familles de requêtes développées

# %% [markdown]
# #### 1. **Consult Controller**
# - **Objectif** : Récupérer des informations spécifiques législatives ou réglementaires (textes, articles, etc.).
# - **Fonctionnalités** :
#   - Obtenir un article spécifique via son `id`.
#   - Récupérer des détails sur une loi ou un texte réglementaire précis.
#
#
#
# #### 2. **Chrono Controller**
# - **Objectif** : Accéder à l'historique et à l'évolution chronologique des textes.
# - **Fonctionnalité** :
#   - Suivre les modifications ou révisions d’un texte au fil du temps.
#
#
#
# #### 3. **List Controller**
# - **Objectif** : Fournir des listes de documents basées sur des critères spécifiques.
# - **Fonctionnalités** :
#   - Lister tous les articles d'un code particulier.
#   - Récupérer la liste des décrets associés à une loi.

# %% [markdown]
# ### Familles de requêtes non développées

# %% [markdown]
# #### 4. **Suggest Controller**
# - **Objectif** : Fournir des suggestions basées sur une recherche partielle.
# - **Fonctionnalités** :
#   - Rechercher un texte via des mots-clés ou des fragments.
#
#
#
# #### 5. **Misc Controller**
# - **Objectif** : Récupérer des métadonnées ou des informations auxiliaires.
# - **Fonctionnalités** :
#   - Obtenir des données complémentaires sur les textes ou documents.
#
#
#
# #### 6. **Search Controller**
# - **Objectif** : Effectuer des recherches globales sur les textes, articles, codes, etc., en fonction de mots-clés ou d'autres critères.
# - **Fonctionnalités** :
#   - Rechercher des textes ou articles pertinents par mots-clés.
#   - Filtrer les résultats en fonction de critères spécifiques.

# %% [markdown]
# ### Listes to do:
# - subdiviser balise html
# - passer apres en .py
#
# Fait:
# - Développer en fonction
# - Quand long télécharger json
# - pas plus que deux boucles for (pas de moyen trouvé)
# - plus utiliser pandas
# - dataframe (flatten)
# - test sur cmf
# - ajout contenu article N vs N-1

# %% [markdown]
# # 1 - LégiFrance API connect

# %% [markdown]
# ## 1.0 - Credential input

# %%
client_id = '2bd5c3ac-5128-4527-b74f-5d3e90e47efb'
client_secret = 'de5cf33d-fbee-4368-8fe9-e803490fe096'

# %% [markdown]
# ## 1.1 - API Get access token

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:41:52) [Clang 15.0.7 ]

# %%
import os
from dotenv import load_dotenv
import requests
from requests_oauthlib import OAuth2Session
import json

# %%
#option 2:
import requests


# URL pour obtenir le jeton
token_url = 'https://sandbox-oauth.piste.gouv.fr/api/oauth/token'

# inject cred for token request
token_data = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    'scope': 'openid'
}

# run the request
response = requests.post(token_url, data=token_data)
response.raise_for_status()  # vérif  erreurs

# récup  jeton
token_info = response.json()


access_token = token_info['access_token']

# %%
def get_token():
    token_url = 'https://sandbox-oauth.piste.gouv.fr/api/oauth/token'
    #inject cred 
    token_data = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    'scope': 'openid'}
    response = requests.post(token_url, data=token_data)
    response.raise_for_status()  # vérif  erreurs
    # récup  jeton
    token_info = response.json()
    global access_token
    access_token = token_info['access_token']
    return access_token

# %% [markdown]
# ## 1.2 - Ping/Pong request Test

# %%
import requests

def ping_pong_test():
    headers_1 = {'accept': 'text/plain', 'Authorization': 'Bearer ' + access_token}
    output = requests.get("https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/ping", headers=headers_1).text
    display(output)

# %%
ping_pong_test()
# Out:
# 'pong'

# %% [markdown]
# # 2 - Requêtes - API calls

# %% [markdown]
# ### 2.1 - Contenu Article - avec Eli (Fait)

# %% [markdown]
# Eli - Identifiant Européen de la Législation:
#
# - Permet d'identifier de façon unique les documents législatifs et réglementaires au sein de la base de données de Légifrance.
#
# - Déclinaison :
#
#   - /eli : Préfixe indiquant qu'il s'agit d'un identifiant ELI.
#   - /decret : Type de texte (ici un décret) peut aussi être un arrêté, une loi, ou d'autres types d'actes normatifs...
#   - /2021/7/13 : Date de publication ou adoption (13 juillet 2021 dans cet exemple).
#   - /PRMD2117108D : Numéro unique du décret
#   - /jo : Indication que le document a été publié dans le Journal Officiel.
#   - /article_1 : Référence à un article spécifique dans le document (ici l'article 1).

# %%
def get_article_byELI(idEliOrAlias):
  headers_2 = {"accept": "application/json","Content-Type": "application/json", 'Authorization': 'Bearer ' + access_token}
  data = {"idEliOrAlias": idEliOrAlias } # exemple: "/eli/decret/2021/7/13/PRMD2117108D/jo/article_1"
  url= "https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleWithIdEliOrAlias"
  response = requests.post(url, headers=headers_2,json=data)
  response_json = response.json()
  return {
        "etat": response_json['article']['textTitles'][1]['etat'],
        "id": response_json['article']['id'],
        "titresTM": response_json['article']['context']['titresTM'],
        "titreLong": response_json['article']['textTitles'][1]["titreLong"],
        "texte": response_json['article']['texte']
    }

# %%
get_article_byELI("/eli/ordonnance/2020/12/9/ECOT2024817R/jo/article_1") 
# exemple: /eli/decret/2021/7/13/PRMD2117108D/jo/article_1
# Out:
# {'etat': 'VIGUEUR',
#  'id': 'JORFARTI000042636235',
#  'titresTM': [],
#  'titreLong': 'Ordonnance n° 2020-1544 du 9 décembre 2020 renforçant le cadre de la lutte contre le blanchiment de capitaux et le financement du terrorisme applicable aux actifs numériques',
#  'texte': "L'article L. 54-10-3 du code monétaire et financier est ainsi modifié : 1° Le premier alinéa est remplacé par les dispositions suivantes : « Avant d'exercer leur activité, les prestataires des services mentionnés aux 1° à 4° de l'article L. 54-10-2 établis en France ou fournissant ces services en France, sont enregistrés par l'Autorité des marchés financiers, qui vérifie si : » ; 2° Le 3° est remplacé par les dispositions suivantes : « 3° Les prestataires sont établis en France ou dans un autre Etat membre de l'Union européenne ou partie à l'accord sur l'Espace économique européen ; » 3° Après le 3°, il est inséré un 4° ainsi rédigé : « 4° Pour les services mentionnés aux 1° et 2° de l'article L. 54-10-2, elle vérifie également que les prestataires sont en mesure de se conformer à leurs obligations en matière de lutte contre le blanchiment des capitaux et le financement du terrorisme, de gel des avoirs et d'interdiction de mise à disposition par la mise en place d'une organisation et de procédures propres à assurer le respect des obligations prévues aux articles L. 561-4-1 à L. 561-5-1, L. 561-10-2 et L. 561-15 et par les règlements pris pour leur application, ainsi qu'au chapitre II du titre VI du présent livre et aux règlements européens portant mesures restrictives pris en application des articles 75 ou 215 du traité sur le fonctionnement de l'Union européenne. « Pour les prestataires des services mentionnés aux 1° et 2° de l'article L. 54-10-2 enregistrés ou immatriculés dans un autre Etat membre de l'Union européenne ou partie à l'accord sur l'Espace économique européen en application de l'article 47 de la directive (UE) 2015/849 du Parlement européen et du Conseil du 20 mai 2015 relative à la prévention de l'utilisation du système financier aux fins du blanchiment de capitaux ou du financement du terrorisme, modifiant le règlement (UE) n° 648/2012 du Parlement européen et du Conseil et abrogeant la directive 2005/60/ CE du Parlement européen et du Conseil et la directive 2006/70/ CE de la Commission, les conditions mentionnées aux 1° et 2° du présent article sont réputées remplies. » ; 4° Au cinquième alinéa, les mots : « A cette fin » sont remplacés par les mots : « Aux fins de l'enregistrement » ; 5° Après le cinquième alinéa, il est inséré un alinéa ainsi rédigé : « Les conditions dans lesquelles un service est considéré comme fourni en France sont fixées par le règlement général de l'Autorité des marchés financiers. » ; 6° Le sixième alinéa est remplacé par les dispositions suivantes : « Toute modification affectant le respect par un prestataire des services mentionnés aux 1° à 4° de l'article L. 54-10-2 des obligations mentionnées ci-dessus doit faire l'objet d'une déclaration auprès de l'Autorité des marchés financiers. » ; 7° Au c, les références : « aux 1° à 3° » sont remplacées par le mot : « ci-dessus » ; 8° Le onzième alinéa est remplacé par les dispositions suivantes : « Les prestataires concernés doivent s'adresser à l'Autorité des marchés financiers pour l'enregistrement prévu au présent article. Celle-ci assure le lien avec l'Autorité de contrôle prudentiel et de résolution pour la procédure d'avis prévue pour l'enregistrement des prestataires des services mentionnés aux 1° à 4° de l'article L. 54-10-2. »"}

# %% [markdown]
# ### 2.2 - Contenu texte type CODE  /consult/code (Fait - pas utilisé)

# %% [markdown]
# Fonction : Permet d'obtenir le contenu complet d'un code juridique

# %%
import json
from IPython.display import HTML
import urllib.parse

def download_json(variable, filename="data.json"):
    json_str = json.dumps(variable)
    json_encoded = urllib.parse.quote(json_str)
    href = f'<a href="data:text/json;charset=utf-8,{json_encoded}" download="{filename}">Télécharger {filename}</a>'
    return HTML(href)

# %%
def get_code(textId,sctCid,abrogated, date):
  headers = {"Authorization": "Bearer " + access_token , "Content-Type": "application/json" }
  BASE_URL = "https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/code"
  data = {
    "textId": textId,         #"LEGITEXT000006073984",  # Code des assurances
    "sctCid": sctCid,         #"LEGIARTI000048769089",  # ID article
    "abrogated": abrogated,   # False,                # exclure les textes abrogés
    "date":date  #"2024-11-15",              # Date de référence
    }
  response = requests.post(BASE_URL, json=data, headers=headers)
  response_json = response.json()
  return response_json

# %%
get_code("LEGITEXT000006073984", "LEGIARTI000042644804","False", "2023-04-08" )

# %% [markdown]
# ### 2.3 - Contenu  d'un article en fonction des versions /consult/getArticleByCid (Fait)

# %% [markdown]
# Objectif : Alimenter le tableau avec le contenu des articles a travers deux fonctions:
# - La première récupère le contenu de l'article a la date d'entrée en vigueur
# - La deuxieme récupère le contenu de l'article a la date de fin

# %% [markdown]
# #### 2.1.3.0 - Test function & debug

# %% [markdown]
# Fonction qui test la récupération de la liste des articles par leur identifiant Cid en retournant le contenu et le message status_code
#
# Exemples identifiant Cid:
#
# - LEGIARTI000028443554 https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000028443554/2014-01-01
#
# - LEGIARTI000028443552 https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000028443552/2014-01-01

# %%
def getArticle_ByCid_allversions_test(article_cid):
  API_URL = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleByCid'
  headers = {'Authorization': 'Bearer ' + access_token, 'Content-Type': 'application/json'}
  data = { 'cid': article_cid }
  response = requests.post(API_URL, json=data, headers=headers)
  response_json = response.json()
  return {"contenu": response.json(),
          "reponse status code ":response.status_code }

# %%
getArticle_ByCid_allversions_test(article_cid= "LEGIARTI000028443554")
# Out:
# {'contenu': {'executionTime': 0,
#   'listArticle': [{'id': 'LEGIARTI000048844354',
#     'idTexte': None,
#     'type': 'AUTONOME',
#     'texte': "Le taux des contributions mentionnées à l'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d'assurance, ce taux est compris entre 0 % et 1 % des primes ou cotisations mentionnées au 2° du même article L. 421-4-1 ; 3° (abrogé) ; 4° Pour la contribution des responsables d'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l'accident a été provoqué par un véhicule utilisé par l'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d'une assurance avec franchise.",
#     'texteHtml': '<p></p><p>Le taux des contributions mentionnées à <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006073984&idArticle=LEGIARTI000048844359&dateTexte=&categorieLien=id" title="Code des assurances - art. L421-4-1 (V)">l\'article L. 421-4-1</a> est fixé par arrêté du ministre chargé des assurances dans les limites suivantes :</p><p>1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ;</p><p>2° Pour la contribution des entreprises d\'assurance, ce taux est compris entre 0 % et 1 % des primes ou cotisations mentionnées au 2° du même article L. 421-4-1 ;</p><p>3° (abrogé) ;</p><p>4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.</p><p></p>',
#     'num': 'L421-4-2',
#     'origine': 'LEGI',
#     'nature': 'Article',
#     'versionArticle': '4.0',
#     'etat': 'VIGUEUR',
#     'dateDebut': 1703980800000,
#     'dateFin': 32472144000000,
#     'dateDebutExtension': 32472144000000,
#     'dateFinExtension': 32472144000000,
#     'inap': None,
#     'ordre': 246956,
#     'context': {'titresTM': [{'debut': '1976-07-16',
#        'fin': '2999-01-01',
#        'titre': 'Partie législative',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006107964',
#        'id': 'LEGISCTA000006107964',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2999-01-01',
#        'titre': "Livre IV : Organisations et régimes particuliers d'assurance",
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006128472',
#        'id': 'LEGISCTA000006128472',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2023-12-08',
#        'titre': 'Titre II : Le fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000006142907',
#        'etat': 'MODIFIE'},
#       {'debut': '2023-12-08',
#        'fin': '2999-01-01',
#        'titre': 'Titre II : Les fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000048523671',
#        'etat': 'VIGUEUR'},
#       {'debut': '2001-07-13',
#        'fin': '2999-01-01',
#        'titre': 'Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006157813',
#        'id': 'LEGISCTA000006157813',
#        'etat': 'VIGUEUR'},
#       {'debut': '2003-08-02',
#        'fin': '2999-01-01',
#        'titre': 'Section I : Dispositions générales.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006174871',
#        'id': 'LEGISCTA000006174871',
#        'etat': 'VIGUEUR'}],
#      'nombreVersionParent': 1,
#      'longeurChemin': 47,
#      'titreTxt': [{'debut': '1976-07-11',
#        'fin': '2999-01-01',
#        'titre': 'Code des assurances',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TITRE_TXT',
#        'cid': 'LEGITEXT000006073984',
#        'id': 'LEGITEXT000006073984',
#        'etat': 'VIGUEUR'}]},
#     'cid': 'LEGIARTI000028443554',
#     'cidTexte': None,
#     'sectionParentCid': 'LEGISCTA000006174871',
#     'sectionParentId': 'LEGISCTA000006174871',
#     'sectionParentTitre': 'Section I : Dispositions générales.',
#     'fullSectionsTitre': "Partie législative &gt; Livre IV : Organisations et régimes particuliers d'assurance &gt; Titre II : Les fonds de garantie &gt; Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages. &gt; Section I : Dispositions générales.",
#     'refInjection': 'IG-20241210',
#     'idTechInjection': 'LEGIARTI000048844354',
#     'idEli': None,
#     'idEliAlias': None,
#     'calipsos': [],
#     'textTitles': [{'id': 'LEGITEXT000006073984',
#       'titre': 'Code des assurances',
#       'titreLong': 'Code des assurances',
#       'etat': 'VIGUEUR',
#       'dateDebut': 205891200000,
#       'dateFin': 32472144000000,
#       'cid': 'LEGITEXT000006073984',
#       'datePubli': 32472144000000,
#       'datePubliComputed': None,
#       'dateTexte': 32472144000000,
#       'dateTexteComputed': None,
#       'nature': 'CODE',
#       'nor': '',
#       'num': '',
#       'numParution': '',
#       'originePubli': '',
#       'appliGeo': None,
#       'codesNomenclatures': [],
#       'visas': None,
#       'nota': None,
#       'notice': None,
#       'travauxPreparatoires': None,
#       'signataires': None,
#       'dossiersLegislatifs': [],
#       'ancienId': None,
#       'appellations': None}],
#     'nota': '',
#     'notaHtml': '',
#     'activitePro': [],
#     'numeroBrochure': [],
#     'numeroBo': None,
#     'conteneurs': [],
#     'lienModifications': [{'textCid': 'JORFTEXT000048727345',
#       'textTitle': 'LOI n°2023-1322 du 29 décembre 2023 - art. 96 (V)',
#       'linkType': 'MODIFIE',
#       'linkOrientation': 'cible',
#       'articleNum': '96',
#       'articleId': 'LEGIARTI000048769089',
#       'natureText': 'LOI',
#       'datePubliTexte': '2023-12-30',
#       'dateSignaTexte': '2023-12-29',
#       'dateDebutCible': '2023-12-31'}],
#     'lienCitations': [{'textCid': 'JORFTEXT000030673448',
#       'textTitle': 'DÉCRET n°2015-608 du 3 juin 2015 - art., v. init.',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'JORFARTI000030673459',
#       'natureText': 'DECRET',
#       'parentCid': None,
#       'numTexte': '2015-608',
#       'datePubli': 1433462400000,
#       'dateDebut': 32472144000000},
#      {'textCid': 'JORFTEXT000049060051',
#       'textTitle': 'Arrêté du 30 janvier 2024 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'LEGITEXT000049064409',
#       'natureText': 'ARRETE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 1706659200000,
#       'dateDebut': 1706745600000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. A421-3 (M)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': 'A421-3',
#       'articleId': 'LEGIARTI000038196109',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1546300800000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. L421-4-1 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'source',
#       'articleNum': 'L421-4-1',
#       'articleId': 'LEGIARTI000048844359',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1703980800000},
#      {'textCid': 'LEGITEXT000006069577',
#       'textTitle': 'Code général des impôts, CGI. - art. 1629 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '1629',
#       'articleId': 'LEGIARTI000030694836',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1433548800000}],
#     'lienConcordes': [],
#     'lienAutres': [],
#     'articleVersions': [{'id': 'LEGIARTI000028443554',
#       'etat': 'MODIFIE',
#       'version': '1.0',
#       'dateDebut': 1388534400000,
#       'dateFin': 1530403200000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000036103228',
#       'etat': 'MODIFIE',
#       'version': '2.0',
#       'dateDebut': 1530403200000,
#       'dateFin': 1546214400000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000037990744',
#       'etat': 'MODIFIE',
#       'version': '3.0',
#       'dateDebut': 1546214400000,
#       'dateFin': 1703980800000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000048844354',
#       'etat': 'VIGUEUR',
#       'version': '4.0',
#       'dateDebut': 1703980800000,
#       'dateFin': 32472144000000,
#       'numero': None,
#       'ordre': None}],
#     'computedNums': ['L421-4-2', '421-4-2'],
#     'versionPrecedente': 'LEGIARTI000037990744',
#     'conditionDiffere': None,
#     'historique': None,
#     'surtitre': None,
#     'renvoi': None,
#     'infosComplementaires': None,
#     'infosComplementairesHtml': None,
#     'infosRestructurationBranche': None,
#     'infosRestructurationBrancheHtml': None,
#     'comporteLiensSP': False,
#     'multipleVersions': False},
#    {'id': 'LEGIARTI000037990744',
#     'idTexte': None,
#     'type': 'AUTONOME',
#     'texte': 'Le taux des contributions mentionnées à l\'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 14 % de la totalité des charges de cette section ; 3° (abrogé) ; 4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.',
#     'texteHtml': '<p></p><p>Le taux des contributions mentionnées à <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006073984&idArticle=LEGIARTI000028443552&dateTexte=&categorieLien=cid">l\'article L. 421-4-1</a> est fixé par arrêté du ministre chargé des assurances dans les limites suivantes :</p><p>1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ;</p><p>2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 14 % de la totalité des charges de cette section ;</p><p>3° (abrogé) ;</p><p>4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.</p><p></p>',
#     'num': 'L421-4-2',
#     'origine': 'LEGI',
#     'nature': 'Article',
#     'versionArticle': '3.0',
#     'etat': 'MODIFIE',
#     'dateDebut': 1546214400000,
#     'dateFin': 1703980800000,
#     'dateDebutExtension': 32472144000000,
#     'dateFinExtension': 32472144000000,
#     'inap': None,
#     'ordre': 246956,
#     'context': {'titresTM': [{'debut': '1976-07-16',
#        'fin': '2999-01-01',
#        'titre': 'Partie législative',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006107964',
#        'id': 'LEGISCTA000006107964',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2999-01-01',
#        'titre': "Livre IV : Organisations et régimes particuliers d'assurance",
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006128472',
#        'id': 'LEGISCTA000006128472',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2023-12-08',
#        'titre': 'Titre II : Le fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000006142907',
#        'etat': 'MODIFIE'},
#       {'debut': '2023-12-08',
#        'fin': '2999-01-01',
#        'titre': 'Titre II : Les fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000048523671',
#        'etat': 'VIGUEUR'},
#       {'debut': '2001-07-13',
#        'fin': '2999-01-01',
#        'titre': 'Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006157813',
#        'id': 'LEGISCTA000006157813',
#        'etat': 'VIGUEUR'},
#       {'debut': '2003-08-02',
#        'fin': '2999-01-01',
#        'titre': 'Section I : Dispositions générales.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006174871',
#        'id': 'LEGISCTA000006174871',
#        'etat': 'VIGUEUR'}],
#      'nombreVersionParent': 1,
#      'longeurChemin': 47,
#      'titreTxt': [{'debut': '1976-07-11',
#        'fin': '2999-01-01',
#        'titre': 'Code des assurances',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TITRE_TXT',
#        'cid': 'LEGITEXT000006073984',
#        'id': 'LEGITEXT000006073984',
#        'etat': 'VIGUEUR'}]},
#     'cid': 'LEGIARTI000028443554',
#     'cidTexte': None,
#     'sectionParentCid': 'LEGISCTA000006174871',
#     'sectionParentId': 'LEGISCTA000006174871',
#     'sectionParentTitre': 'Section I : Dispositions générales.',
#     'fullSectionsTitre': "Partie législative &gt; Livre IV : Organisations et régimes particuliers d'assurance &gt; Titre II : Les fonds de garantie &gt; Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages. &gt; Section I : Dispositions générales.",
#     'refInjection': 'IG-20241209',
#     'idTechInjection': 'LEGIARTI000037990744',
#     'idEli': None,
#     'idEliAlias': None,
#     'calipsos': [],
#     'textTitles': [{'id': 'LEGITEXT000006073984',
#       'titre': 'Code des assurances',
#       'titreLong': 'Code des assurances',
#       'etat': 'VIGUEUR',
#       'dateDebut': 205891200000,
#       'dateFin': 32472144000000,
#       'cid': 'LEGITEXT000006073984',
#       'datePubli': 32472144000000,
#       'datePubliComputed': None,
#       'dateTexte': 32472144000000,
#       'dateTexteComputed': None,
#       'nature': 'CODE',
#       'nor': '',
#       'num': '',
#       'numParution': '',
#       'originePubli': '',
#       'appliGeo': None,
#       'codesNomenclatures': [],
#       'visas': None,
#       'nota': None,
#       'notice': None,
#       'travauxPreparatoires': None,
#       'signataires': None,
#       'dossiersLegislatifs': [],
#       'ancienId': None,
#       'appellations': None}],
#     'nota': '',
#     'notaHtml': '',
#     'activitePro': [],
#     'numeroBrochure': [],
#     'numeroBo': None,
#     'conteneurs': [],
#     'lienModifications': [{'textCid': 'JORFTEXT000037882341',
#       'textTitle': 'LOI n°2018-1317 du 28 décembre 2018 - art. 124',
#       'linkType': 'MODIFIE',
#       'linkOrientation': 'cible',
#       'articleNum': '124',
#       'articleId': 'LEGIARTI000037935610',
#       'natureText': 'LOI',
#       'datePubliTexte': '2018-12-30',
#       'dateSignaTexte': '2018-12-28',
#       'dateDebutCible': '2018-12-31'}],
#     'lienCitations': [{'textCid': 'JORFTEXT000030673448',
#       'textTitle': 'DÉCRET n°2015-608 du 3 juin 2015 - art., v. init.',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'JORFARTI000030673459',
#       'natureText': 'DECRET',
#       'parentCid': None,
#       'numTexte': '2015-608',
#       'datePubli': 1433462400000,
#       'dateDebut': 32472144000000},
#      {'textCid': 'JORFTEXT000049060051',
#       'textTitle': 'Arrêté du 30 janvier 2024 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'LEGITEXT000049064409',
#       'natureText': 'ARRETE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 1706659200000,
#       'dateDebut': 1706745600000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. A421-3 (M)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': 'A421-3',
#       'articleId': 'LEGIARTI000038196109',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1546300800000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. L421-4-1',
#       'linkType': 'CITATION',
#       'linkOrientation': 'source',
#       'articleNum': 'L421-4-1',
#       'articleId': 'LEGIARTI000028443552',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1388534400000},
#      {'textCid': 'LEGITEXT000006069577',
#       'textTitle': 'Code général des impôts, CGI. - art. 1629 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '1629',
#       'articleId': 'LEGIARTI000030694836',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1433548800000}],
#     'lienConcordes': [],
#     'lienAutres': [],
#     'articleVersions': [{'id': 'LEGIARTI000028443554',
#       'etat': 'MODIFIE',
#       'version': '1.0',
#       'dateDebut': 1388534400000,
#       'dateFin': 1530403200000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000036103228',
#       'etat': 'MODIFIE',
#       'version': '2.0',
#       'dateDebut': 1530403200000,
#       'dateFin': 1546214400000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000037990744',
#       'etat': 'MODIFIE',
#       'version': '3.0',
#       'dateDebut': 1546214400000,
#       'dateFin': 1703980800000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000048844354',
#       'etat': 'VIGUEUR',
#       'version': '4.0',
#       'dateDebut': 1703980800000,
#       'dateFin': 32472144000000,
#       'numero': None,
#       'ordre': None}],
#     'computedNums': ['L421-4-2', '421-4-2'],
#     'versionPrecedente': 'LEGIARTI000036103228',
#     'conditionDiffere': None,
#     'historique': None,
#     'surtitre': None,
#     'renvoi': None,
#     'infosComplementaires': None,
#     'infosComplementairesHtml': None,
#     'infosRestructurationBranche': None,
#     'infosRestructurationBrancheHtml': None,
#     'comporteLiensSP': False,
#     'multipleVersions': False},
#    {'id': 'LEGIARTI000036103228',
#     'idTexte': None,
#     'type': 'AUTONOME',
#     'texte': 'Le taux des contributions mentionnées à l\'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; 3° (abrogé) ; 4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.',
#     'texteHtml': '<p></p><p>Le taux des contributions mentionnées à <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006073984&idArticle=LEGIARTI000028443552&dateTexte=&categorieLien=cid">l\'article L. 421-4-1</a> est fixé par arrêté du ministre chargé des assurances dans les limites suivantes :</p><p></p><p>1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ;</p><p>2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ;</p><p>3° (abrogé) ;</p><p>4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.</p><p></p>',
#     'num': 'L421-4-2',
#     'origine': 'LEGI',
#     'nature': 'Article',
#     'versionArticle': '2.0',
#     'etat': 'MODIFIE',
#     'dateDebut': 1530403200000,
#     'dateFin': 1546214400000,
#     'dateDebutExtension': 32472144000000,
#     'dateFinExtension': 32472144000000,
#     'inap': None,
#     'ordre': 246956,
#     'context': {'titresTM': [{'debut': '1976-07-16',
#        'fin': '2999-01-01',
#        'titre': 'Partie législative',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006107964',
#        'id': 'LEGISCTA000006107964',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2999-01-01',
#        'titre': "Livre IV : Organisations et régimes particuliers d'assurance",
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006128472',
#        'id': 'LEGISCTA000006128472',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2023-12-08',
#        'titre': 'Titre II : Le fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000006142907',
#        'etat': 'MODIFIE'},
#       {'debut': '2023-12-08',
#        'fin': '2999-01-01',
#        'titre': 'Titre II : Les fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000048523671',
#        'etat': 'VIGUEUR'},
#       {'debut': '2001-07-13',
#        'fin': '2999-01-01',
#        'titre': 'Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006157813',
#        'id': 'LEGISCTA000006157813',
#        'etat': 'VIGUEUR'},
#       {'debut': '2003-08-02',
#        'fin': '2999-01-01',
#        'titre': 'Section I : Dispositions générales.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006174871',
#        'id': 'LEGISCTA000006174871',
#        'etat': 'VIGUEUR'}],
#      'nombreVersionParent': 1,
#      'longeurChemin': 47,
#      'titreTxt': [{'debut': '1976-07-11',
#        'fin': '2999-01-01',
#        'titre': 'Code des assurances',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TITRE_TXT',
#        'cid': 'LEGITEXT000006073984',
#        'id': 'LEGITEXT000006073984',
#        'etat': 'VIGUEUR'}]},
#     'cid': 'LEGIARTI000028443554',
#     'cidTexte': None,
#     'sectionParentCid': 'LEGISCTA000006174871',
#     'sectionParentId': 'LEGISCTA000006174871',
#     'sectionParentTitre': 'Section I : Dispositions générales.',
#     'fullSectionsTitre': "Partie législative &gt; Livre IV : Organisations et régimes particuliers d'assurance &gt; Titre II : Le fonds de garantie &gt; Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages. &gt; Section I : Dispositions générales.",
#     'refInjection': 'IG-20241209',
#     'idTechInjection': 'LEGIARTI000036103228',
#     'idEli': None,
#     'idEliAlias': None,
#     'calipsos': [],
#     'textTitles': [{'id': 'LEGITEXT000006073984',
#       'titre': 'Code des assurances',
#       'titreLong': 'Code des assurances',
#       'etat': 'VIGUEUR',
#       'dateDebut': 205891200000,
#       'dateFin': 32472144000000,
#       'cid': 'LEGITEXT000006073984',
#       'datePubli': 32472144000000,
#       'datePubliComputed': None,
#       'dateTexte': 32472144000000,
#       'dateTexteComputed': None,
#       'nature': 'CODE',
#       'nor': '',
#       'num': '',
#       'numParution': '',
#       'originePubli': '',
#       'appliGeo': None,
#       'codesNomenclatures': [],
#       'visas': None,
#       'nota': None,
#       'notice': None,
#       'travauxPreparatoires': None,
#       'signataires': None,
#       'dossiersLegislatifs': [],
#       'ancienId': None,
#       'appellations': None}],
#     'nota': "Conformément à l'article 15 de l'ordonnance n° 2017-1609 du 27 novembre 2017, ces dispositions s'appliquent aux contrats d'assurance conclus ou renouvelés à compter de la date d'entrée en vigueur de ladite ordonnance qui sera fixée par décret et au plus tard le 1er juillet 2018.",
#     'notaHtml': "<p>Conformément à l'article 15 de l'ordonnance n° 2017-1609 du 27 novembre 2017, ces dispositions s'appliquent aux contrats d'assurance conclus ou renouvelés à compter de la date d'entrée en vigueur de ladite ordonnance qui sera fixée par décret et au plus tard le 1er juillet 2018.</p>",
#     'activitePro': [],
#     'numeroBrochure': [],
#     'numeroBo': None,
#     'conteneurs': [],
#     'lienModifications': [{'textCid': 'JORFTEXT000036100443',
#       'textTitle': 'Ordonnance n°2017-1609 du 27 novembre 2017 - art. 4',
#       'linkType': 'MODIFIE',
#       'linkOrientation': 'cible',
#       'articleNum': '4',
#       'articleId': 'LEGIARTI000036101166',
#       'natureText': 'ORDONNANCE',
#       'datePubliTexte': '2017-11-28',
#       'dateSignaTexte': '2017-11-27',
#       'dateDebutCible': '2018-07-01'}],
#     'lienCitations': [{'textCid': 'JORFTEXT000030673448',
#       'textTitle': 'DÉCRET n°2015-608 du 3 juin 2015 - art., v. init.',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'JORFARTI000030673459',
#       'natureText': 'DECRET',
#       'parentCid': None,
#       'numTexte': '2015-608',
#       'datePubli': 1433462400000,
#       'dateDebut': 32472144000000},
#      {'textCid': 'JORFTEXT000049060051',
#       'textTitle': 'Arrêté du 30 janvier 2024 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'LEGITEXT000049064409',
#       'natureText': 'ARRETE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 1706659200000,
#       'dateDebut': 1706745600000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. A421-3 (M)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': 'A421-3',
#       'articleId': 'LEGIARTI000038196109',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1546300800000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. L421-4-1',
#       'linkType': 'CITATION',
#       'linkOrientation': 'source',
#       'articleNum': 'L421-4-1',
#       'articleId': 'LEGIARTI000028443552',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1388534400000},
#      {'textCid': 'LEGITEXT000006069577',
#       'textTitle': 'Code général des impôts, CGI. - art. 1629 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '1629',
#       'articleId': 'LEGIARTI000030694836',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1433548800000}],
#     'lienConcordes': [],
#     'lienAutres': [],
#     'articleVersions': [{'id': 'LEGIARTI000028443554',
#       'etat': 'MODIFIE',
#       'version': '1.0',
#       'dateDebut': 1388534400000,
#       'dateFin': 1530403200000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000036103228',
#       'etat': 'MODIFIE',
#       'version': '2.0',
#       'dateDebut': 1530403200000,
#       'dateFin': 1546214400000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000037990744',
#       'etat': 'MODIFIE',
#       'version': '3.0',
#       'dateDebut': 1546214400000,
#       'dateFin': 1703980800000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000048844354',
#       'etat': 'VIGUEUR',
#       'version': '4.0',
#       'dateDebut': 1703980800000,
#       'dateFin': 32472144000000,
#       'numero': None,
#       'ordre': None}],
#     'computedNums': ['L421-4-2', '421-4-2'],
#     'versionPrecedente': 'LEGIARTI000028443554',
#     'conditionDiffere': None,
#     'historique': None,
#     'surtitre': None,
#     'renvoi': None,
#     'infosComplementaires': None,
#     'infosComplementairesHtml': None,
#     'infosRestructurationBranche': None,
#     'infosRestructurationBrancheHtml': None,
#     'comporteLiensSP': False,
#     'multipleVersions': False},
#    {'id': 'LEGIARTI000028443554',
#     'idTexte': None,
#     'type': 'AUTONOME',
#     'texte': 'Le taux des contributions mentionnées à l\'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; 3° Pour la contribution des entreprises d\'assurance au titre de la section " Opérations du fonds de garantie résultant de la défaillance d\'entreprises d\'assurance dommages ” prévue au 3° dudit article, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; 4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.',
#     'texteHtml': '<div align="left">Le taux des contributions mentionnées à <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006073984&idArticle=LEGIARTI000028443552&dateTexte=&categorieLien=cid" title="Code des assurances - art. L421-4-1 (V)">l\'article L. 421-4-1</a> est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : <br/><br/>1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; <br/><br/>2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; <br/><br/>3° Pour la contribution des entreprises d\'assurance au titre de la section " Opérations du fonds de garantie résultant de la défaillance d\'entreprises d\'assurance dommages ” prévue au 3° dudit article, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; <br/><br/>4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.<br/></div>',
#     'num': 'L421-4-2',
#     'origine': 'LEGI',
#     'nature': 'Article',
#     'versionArticle': '1.0',
#     'etat': 'MODIFIE',
#     'dateDebut': 1388534400000,
#     'dateFin': 1530403200000,
#     'dateDebutExtension': 32472144000000,
#     'dateFinExtension': 32472144000000,
#     'inap': None,
#     'ordre': 246956,
#     'context': {'titresTM': [{'debut': '1976-07-16',
#        'fin': '2999-01-01',
#        'titre': 'Partie législative',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006107964',
#        'id': 'LEGISCTA000006107964',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2999-01-01',
#        'titre': "Livre IV : Organisations et régimes particuliers d'assurance",
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006128472',
#        'id': 'LEGISCTA000006128472',
#        'etat': 'VIGUEUR'},
#       {'debut': '1976-07-21',
#        'fin': '2023-12-08',
#        'titre': 'Titre II : Le fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000006142907',
#        'etat': 'MODIFIE'},
#       {'debut': '2023-12-08',
#        'fin': '2999-01-01',
#        'titre': 'Titre II : Les fonds de garantie',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006142907',
#        'id': 'LEGISCTA000048523671',
#        'etat': 'VIGUEUR'},
#       {'debut': '2001-07-13',
#        'fin': '2999-01-01',
#        'titre': 'Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006157813',
#        'id': 'LEGISCTA000006157813',
#        'etat': 'VIGUEUR'},
#       {'debut': '2003-08-02',
#        'fin': '2999-01-01',
#        'titre': 'Section I : Dispositions générales.',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TM/TM/TM/TM/TITRE_TM',
#        'cid': 'LEGISCTA000006174871',
#        'id': 'LEGISCTA000006174871',
#        'etat': 'VIGUEUR'}],
#      'nombreVersionParent': 1,
#      'longeurChemin': 47,
#      'titreTxt': [{'debut': '1976-07-11',
#        'fin': '2999-01-01',
#        'titre': 'Code des assurances',
#        'xPath': '/ARTICLE/CONTEXTE/TEXTE/TITRE_TXT',
#        'cid': 'LEGITEXT000006073984',
#        'id': 'LEGITEXT000006073984',
#        'etat': 'VIGUEUR'}]},
#     'cid': 'LEGIARTI000028443554',
#     'cidTexte': None,
#     'sectionParentCid': 'LEGISCTA000006174871',
#     'sectionParentId': 'LEGISCTA000006174871',
#     'sectionParentTitre': 'Section I : Dispositions générales.',
#     'fullSectionsTitre': "Partie législative &gt; Livre IV : Organisations et régimes particuliers d'assurance &gt; Titre II : Le fonds de garantie &gt; Chapitre Ier : Le Fonds de garantie des assurances obligatoires de dommages. &gt; Section I : Dispositions générales.",
#     'refInjection': 'IG-20241209',
#     'idTechInjection': 'LEGIARTI000028443554',
#     'idEli': None,
#     'idEliAlias': None,
#     'calipsos': [],
#     'textTitles': [{'id': 'LEGITEXT000006073984',
#       'titre': 'Code des assurances',
#       'titreLong': 'Code des assurances',
#       'etat': 'VIGUEUR',
#       'dateDebut': 205891200000,
#       'dateFin': 32472144000000,
#       'cid': 'LEGITEXT000006073984',
#       'datePubli': 32472144000000,
#       'datePubliComputed': None,
#       'dateTexte': 32472144000000,
#       'dateTexteComputed': None,
#       'nature': 'CODE',
#       'nor': '',
#       'num': '',
#       'numParution': '',
#       'originePubli': '',
#       'appliGeo': None,
#       'codesNomenclatures': [],
#       'visas': None,
#       'nota': None,
#       'notice': None,
#       'travauxPreparatoires': None,
#       'signataires': None,
#       'dossiersLegislatifs': [],
#       'ancienId': None,
#       'appellations': None}],
#     'nota': '',
#     'notaHtml': '',
#     'activitePro': [],
#     'numeroBrochure': [],
#     'numeroBo': None,
#     'conteneurs': [],
#     'lienModifications': [{'textCid': 'JORFTEXT000028400921',
#       'textTitle': 'LOI n°2013-1279\n du 29 décembre 2013 - art. 62',
#       'linkType': 'CREE',
#       'linkOrientation': 'cible',
#       'articleNum': '62',
#       'articleId': 'LEGIARTI000028428576',
#       'natureText': 'LOI',
#       'datePubliTexte': '2013-12-30',
#       'dateSignaTexte': '2013-12-29',
#       'dateDebutCible': '2013-12-31'}],
#     'lienCitations': [{'textCid': 'JORFTEXT000030673448',
#       'textTitle': 'DÉCRET n°2015-608 du 3 juin 2015 - art., v. init.',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'JORFARTI000030673459',
#       'natureText': 'DECRET',
#       'parentCid': None,
#       'numTexte': '2015-608',
#       'datePubli': 1433462400000,
#       'dateDebut': 32472144000000},
#      {'textCid': 'JORFTEXT000049060051',
#       'textTitle': 'Arrêté du 30 janvier 2024 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '',
#       'articleId': 'LEGITEXT000049064409',
#       'natureText': 'ARRETE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 1706659200000,
#       'dateDebut': 1706745600000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. A421-3 (M)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': 'A421-3',
#       'articleId': 'LEGIARTI000038196109',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1546300800000},
#      {'textCid': 'LEGITEXT000006073984',
#       'textTitle': 'Code des assurances - art. L421-4-1 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'source',
#       'articleNum': 'L421-4-1',
#       'articleId': 'LEGIARTI000028443552',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1388534400000},
#      {'textCid': 'LEGITEXT000006069577',
#       'textTitle': 'Code général des impôts, CGI. - art. 1629 (V)',
#       'linkType': 'CITATION',
#       'linkOrientation': 'cible',
#       'articleNum': '1629',
#       'articleId': 'LEGIARTI000030694836',
#       'natureText': 'CODE',
#       'parentCid': None,
#       'numTexte': '',
#       'datePubli': 32472144000000,
#       'dateDebut': 1433548800000}],
#     'lienConcordes': [],
#     'lienAutres': [],
#     'articleVersions': [{'id': 'LEGIARTI000028443554',
#       'etat': 'MODIFIE',
#       'version': '1.0',
#       'dateDebut': 1388534400000,
#       'dateFin': 1530403200000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000036103228',
#       'etat': 'MODIFIE',
#       'version': '2.0',
#       'dateDebut': 1530403200000,
#       'dateFin': 1546214400000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000037990744',
#       'etat': 'MODIFIE',
#       'version': '3.0',
#       'dateDebut': 1546214400000,
#       'dateFin': 1703980800000,
#       'numero': None,
#       'ordre': None},
#      {'id': 'LEGIARTI000048844354',
#       'etat': 'VIGUEUR',
#       'version': '4.0',
#       'dateDebut': 1703980800000,
#       'dateFin': 32472144000000,
#       'numero': None,
#       'ordre': None}],
#     'computedNums': ['L421-4-2', '421-4-2'],
#     'versionPrecedente': None,
#     'conditionDiffere': None,
#     'historique': None,
#     'surtitre': None,
#     'renvoi': None,
#     'infosComplementaires': None,
#     'infosComplementairesHtml': None,
#     'infosRestructurationBranche': None,
#     'infosRestructurationBrancheHtml': None,
#     'comporteLiensSP': False,
#     'multipleVersions': False}]},
#  'reponse status code ': 200}

# %% [markdown]
# #### 2.1.3.1 - Get the last version of an article (by Cid)

# %%
from datetime import datetime

def format_date(timestamp_ms):
    timestamp_s = timestamp_ms // 1000  # Convertir millisecondes en secondes
    return datetime.utcfromtimestamp(timestamp_s).strftime('%Y-%m-%d')

def getArticle_ByCid_last_version(article_cid):
  API_URL = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleByCid'
  headers = {'Authorization': 'Bearer ' + access_token, 'Content-Type': 'application/json'}
  data = { 'cid': article_cid }
  response = requests.post(API_URL, json=data, headers=headers)
  response_json = response.json()
  return {"Date Debut:" : format_date(response.json()['listArticle'][0]['dateDebut']),
          "Date Fin:": format_date(response.json()['listArticle'][0]['dateFin']),
          "Version:": response.json()['listArticle'][0]['versionArticle'],
          "Texte:": response.json()['listArticle'][0]['texte']
          }

# %%
getArticle_ByCid_last_version("LEGIARTI000047390103")
# Out:
# {'Date Debut:': '2023-04-03',
#  'Date Fin:': '2999-01-01',
#  'Version:': '1.0',
#  'Texte:': "La demande d'agrément est accompagnée des éléments suivants : 1° La convention constitutive signée par les représentants légaux de l'ensemble des entreprises d'assurance qui commercialisent, au moment du dépôt de la demande, des produits d'assurance contre les risques climatiques en agriculture bénéficiant de l'aide prévue au deuxième alinéa de l'article L. 361-4 du code rural et de la pêche maritime ; 2° Une analyse économique de l'impact du groupement sur le marché de la couverture des risques climatiques au regard de l'intensité concurrentielle du secteur assurantiel concerné et des gains économiques attendus pour les exploitants agricoles ; 3° L'avis de l'Autorité de la concurrence mentionné au III de l'article L. 442-1-2 ; 4° Un compte-rendu exhaustif ainsi que l'ensemble des contributions écrites de la consultation publique mentionnée à l'article L. 442-1-2."}

# %% [markdown]
# #### 2.1.3.2 - Get all versions of an artcile (by Cid )

# %%
import requests

def get_articles_by_cid_all_versions(article_cid):
    API_URL = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleByCid'
    headers = {'Authorization': 'Bearer ' + access_token, 'Content-Type': 'application/json'}
    data = {'cid': article_cid}

    response = requests.post(API_URL, json=data, headers=headers)
    response_json = response.json()

    # Liste des articles récupérés
    articles = response_json.get('listArticle', [])

    # Résultats formatés
    formatted_articles = []
    for article in articles:
        formatted_articles.append({
            "Date Debut": format_date(article.get('dateDebut')),
            "Date Fin": format_date(article.get('dateFin')),
            "Version": article.get('versionArticle'),
            "Texte": article.get('texte')
        })

    return formatted_articles

# %%
get_articles_by_cid_all_versions("LEGIARTI000028443554")
# Out:
# [{'Date Debut': '2023-12-31',
#   'Date Fin': '2999-01-01',
#   'Version': '4.0',
#   'Texte': "Le taux des contributions mentionnées à l'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d'assurance, ce taux est compris entre 0 % et 1 % des primes ou cotisations mentionnées au 2° du même article L. 421-4-1 ; 3° (abrogé) ; 4° Pour la contribution des responsables d'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l'accident a été provoqué par un véhicule utilisé par l'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d'une assurance avec franchise."},
#  {'Date Debut': '2018-12-31',
#   'Date Fin': '2023-12-31',
#   'Version': '3.0',
#   'Texte': 'Le taux des contributions mentionnées à l\'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 14 % de la totalité des charges de cette section ; 3° (abrogé) ; 4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.'},
#  {'Date Debut': '2018-07-01',
#   'Date Fin': '2018-12-31',
#   'Version': '2.0',
#   'Texte': 'Le taux des contributions mentionnées à l\'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; 3° (abrogé) ; 4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.'},
#  {'Date Debut': '2014-01-01',
#   'Date Fin': '2018-07-01',
#   'Version': '1.0',
#   'Texte': 'Le taux des contributions mentionnées à l\'article L. 421-4-1 est fixé par arrêté du ministre chargé des assurances dans les limites suivantes : 1° Pour la contribution des assurés, ce taux est compris entre 0 % et 2 % des primes mentionnées au 1° du même article ; 2° Pour la contribution des entreprises d\'assurance au titre de la section " automobile ”, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; 3° Pour la contribution des entreprises d\'assurance au titre de la section " Opérations du fonds de garantie résultant de la défaillance d\'entreprises d\'assurance dommages ” prévue au 3° dudit article, ce taux est compris entre 0 % et 12 % de la totalité des charges de cette section ; 4° Pour la contribution des responsables d\'accidents non assurés, ce taux est fixé à 10 % des indemnités restant à leur charge. Toutefois, ce taux peut être ramené à 5 % lorsque l\'accident a été provoqué par un véhicule utilisé par l\'Etat ou par un Etat étranger. Il est également ramené à 5 % des indemnités restant à leur propre charge pour les bénéficiaires d\'une assurance avec franchise.'}]

# %% [markdown]
# #### 2.1.3.3 - Get new article content by cid and implementation date for table

# %% [markdown]
# Fonction pour remplissage de la premiere colonne du tableau qui correspond a la nouvelle version de l'article.
#
# La fonction prend en entrée deux paramètres l'identifiant de l'article (Cid) et la date d'entrée en vigueur (start_date).
#
# Attention : La fonction ne fonctionne pas pour tous les articles.

# %%
import requests
from datetime import datetime

def get_article_text_by_cid_and_implementDate(article_cid, start_date):
    API_URL = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleByCid'
    headers = {'Authorization': 'Bearer ' + access_token, 'Content-Type': 'application/json'}
    data = {'cid': article_cid}

    response = requests.post(API_URL, json=data, headers=headers)
    response_json = response.json()

    # Convertir la date en millisecondes depuis l'époque Unix
    start_date_timestamp = int(datetime.strptime(start_date, "%Y-%m-%d").timestamp() * 1000)

    # Parcourir les articles du tableau pour trouver une correspondance
    articles = response_json.get('listArticle', []) # listArticle output json key de la requete
    for article in articles:
        if article.get('dateDebut') == start_date_timestamp:
            return article.get('texte', "Texte non disponible")

    # Si aucun article ne correspond
    return "Aucun article trouvé pour la date de début donnée."

# %%
get_article_text_by_cid_and_implementDate(article_cid = "LEGIARTI000028443554",  start_date= "2018-07-01")
# Ok : "LEGIARTI000028443554",  "2018-07-01"
# KO : "LEGIARTI000048656110"  "2023-12-23"
# Out:
# 'Aucun article trouvé pour la date de début donnée.'

# %% [markdown]
# #### 2.1.3.3 - Get old article content by cid and end date for table

# %%
import requests
from datetime import datetime

def get_article_text_by_cid_and_end_date(article_cid, end_date):
    API_URL = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleByCid'
    headers = {'Authorization': 'Bearer ' + access_token, 'Content-Type': 'application/json'}
    data = {'cid': article_cid}

    response = requests.post(API_URL, json=data, headers=headers)
    response_json = response.json()

    # Convertir la date en millisecondes depuis l'époque Unix
    end_date_timestamp = int(datetime.strptime(end_date, "%d-%m-%Y").timestamp() * 1000) #(ko: %Y-%m-%d ) (ko:"%d-%m-%Y" )

    # Parcourir les articles pour trouver une correspondance
    articles = response_json.get('listArticle', [])
    for article in articles:
        if article.get('dateFin') == end_date_timestamp:
            return article.get('texte', "Texte non disponible")

    # Si aucun article ne correspond
    return "Aucun article trouvé pour la date de début donnée."

# %%
get_article_text_by_cid_and_end_date("LEGIARTI000048243369","25-10-2023") #KO :"LEGIARTI000046918899","2023-11-01"
# Out:
# 'Aucun article trouvé pour la date de début donnée.'

# %% [markdown]
# ### 2.4 - Contenu d'un dossier législatif JORF /consult/dossierLegislatif (Fait)

# %% [markdown]
# Récupère le contenu d'un dossier legislatif par son identifiant.
#
# Input : Identifiant technique du dossier législatif "id": "JORFDOLE000038049286"

# %%
import requests
import json

def dossierLegislatif(id): #JORFDOLE000038049286 
	headers = {'accept': 'application/json','Content-Type': 'application/json','Authorization': 'Bearer ' + access_token}
	url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/dossierLegislatif'
	data = {"id":id}
	reponse = requests.post(headers = headers , url= url, json= data)
	reponse_json = reponse.json()
	return reponse_json

# %%
dossierLegislatif("JORFARTI000042636235")
# Out:
# {'executionTime': 0, 'dereferenced': False, 'dossierLegislatif': None}

# %% [markdown]
# ### 2.5 - Contenu texte fonds LEGI /consult/legiPart ( Fait )

# %% [markdown]
# Récupère des informations précises sur des articles de loi, des codes ou d'autres textes juridiques a partir d'identifiant ("textId") et de sa date de vigueur:

# %%
def legipart(textId, date): # LEGITEXT000006075116 2021-04-15
  url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/legiPart'
  headers = {'accept': 'application/json','Content-Type': 'application/json', 'Authorization': 'Bearer ' + access_token}
  data = { #"searchedString":"constitution 1958",
        "date": date,
        "textId":textId }
  response = requests.post(url= url, headers =headers, json= data )
  return response.json()

# %%
legipart("LEGIARTI000042644804", "2021-04-15")
# Out:
# {'executionTime': 12,
#  'dereferenced': False,
#  'id': 'LEGITEXT000042644801_11-12-2020',
#  'idConteneur': None,
#  'cid': 'JORFTEXT000042636234',
#  'title': 'Ordonnance n° 2020-1544 du 9 décembre 2020 renforçant le cadre de la lutte contre le blanchiment de capitaux et le financement du terrorisme applicable aux actifs numériques',
#  'nor': 'ECOT2024817R',
#  'eli': None,
#  'alias': None,
#  'jorfText': 'JORF n°0298 du 10 décembre 2020',
#  'jurisState': 'Vigueur',
#  'visa': '<p align="left"><br/>Le Président de la République,<br/>Sur le rapport du Premier ministre et du ministre de l\'économie, des finances et de la relance,<br/>Vu la Constitution, notamment son article 38 ;<br/>Vu le traité sur le fonctionnement de l\'Union européenne, notamment ses articles 75 et 215 ;<br/>Vu la directive (UE) 2015/849 du Parlement européen et du Conseil du 20 mai 2015 relative à la prévention de l\'utilisation du système financier aux fins du blanchiment de capitaux ou du financement du terrorisme, modifiant le règlement (UE) n° 648/2012 du Parlement européen et du Conseil et abrogeant la directive 2005/60/CE du Parlement européen et du Conseil et la directive 2006/70/CE de la Commission, notamment son article 4 ;<br/>Vu la directive (UE) 2018/843 du Parlement européen et du Conseil du 30 mai 2018 modifiant la directive (UE) 2015/849 relative à la prévention de l\'utilisation du système financier aux fins du blanchiment de capitaux ou du financement du terrorisme ainsi que les directives 2009/138/CE et 2013/36/UE, notamment son article 1er ;<br/>Vu le code de justice administrative notamment son article R. 123-20 ;<br/>Vu le code monétaire et financier ;<br/>Vu la loi n° 78-17 du 6 janvier 1978 modifiée relative à l\'informatique, aux fichiers et aux libertés ;<br/>Vu la loi n° 2019-486 du 22 mai 2019 modifiée relative à la croissance et la transformation des entreprises, notamment son article 203 ;<br/>Vu la loi n° 2020-290 du 23 mars 2020 d\'urgence pour faire face à l\'épidémie de covid-19 modifiée, notamment son article 14 ;<br/>Vu l\'avis du Comité consultatif de la législation et de la réglementation financières en date du 13 novembre 2020 ;<br/>Le Conseil d\'Etat (section des finances) entendu,<br/>Le conseil des ministres entendu,<br/>Ordonne :</p>',
#  'modifDate': '2020-12-11',
#  'jurisDate': '2020-12-11',
#  'dateDebutVersion': '2020-12-11',
#  'dateFinVersion': '2999-01-01',
#  'signers': '<p align="left"><br/>Fait le 9 décembre 2020.</p><p align="left"><br/>Emmanuel Macron<br/>Par le Président de la République :</p><p align="left"><br/>Le Premier ministre,<br/>Jean Castex</p><p align="left"><br/>Le ministre de l\'économie, des finances et de la relance,<br/>Bruno Le Maire</p><p align="left"><br/>Le ministre des outre-mer,<br/>Sébastien Lecornu</p>',
#  'prepWork': '',
#  'dateParution': 1607558400000,
#  'dateTexte': None,
#  'numParution': '0298',
#  'notice': None,
#  'nota': '',
#  'inap': False,
#  'textNumber': None,
#  'textAbroge': False,
#  'etat': None,
#  'dossiersLegislatifs': [{'id': 'JORFDOLE000042645365',
#    'ancienId': None,
#    'origine': None,
#    'url': None,
#    'nature': None,
#    'titre': 'Ordonnance n° 2020-1544 du 9 décembre 2020 renforçant le cadre de la lutte contre le blanchiment de capitaux et le financement du terrorisme applicable aux actifs numériques',
#    'type': None,
#    'dateCreation': None,
#    'dateDerniereModification': 1618963200000,
#    'legislature': None,
#    'echeancier': '',
#    'dateMajEcheancier': None,
#    'exposeMotif': None,
#    'arborescence': None,
#    'dossiers': [],
#    'refInjection': None,
#    'idTechInjection': None}],
#  'nature': 'ORDONNANCE',
#  'resume': None,
#  'rectificatif': None,
#  'motsCles': [],
#  'appellations': [],
#  'liens': [],
#  'observations': None,
#  'sections': [],
#  'articles': [{'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644802',
#    'cid': 'JORFARTI000042636235',
#    'intOrdre': 524287,
#    'etat': 'VIGUEUR',
#    'num': '1',
#    'path': '/LEGIARTI000042644802',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648495&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L54-10-3 (V)">  Art. L54-10-3</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L54-10-3 (V)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L54-10-3',
#      'articleId': 'LEGIARTI000042648495',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644804',
#    'cid': 'JORFARTI000042636236',
#    'intOrdre': 1048574,
#    'etat': 'VIGUEUR',
#    'num': '2',
#    'path': '/LEGIARTI000042644804',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648498&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L54-10-4 (M)">  Art. L54-10-4</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L54-10-4 (M)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L54-10-4',
#      'articleId': 'LEGIARTI000042648498',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': 'Version en vigueur à partir du 01 janvier 2999',
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644806',
#    'cid': 'JORFARTI000042636237',
#    'intOrdre': 1572861,
#    'etat': 'VIGUEUR',
#    'num': '3',
#    'path': '/LEGIARTI000042644806',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648501&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L54-10-5 (V)">  Art. L54-10-5</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L54-10-5 (V)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L54-10-5',
#      'articleId': 'LEGIARTI000042648501',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644808',
#    'cid': 'JORFARTI000042636238',
#    'intOrdre': 2097148,
#    'etat': 'VIGUEUR',
#    'num': '4',
#    'path': '/LEGIARTI000042644808',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648575&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L561-2 (M)">  Art. L561-2</a>, <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648544&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L561-7 (V)">  Art. L561-7</a>, <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648537&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L561-14 (V)">  Art. L561-14</a>, <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648504&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L561-20 (V)">  Art. L561-20</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L561-14 (V)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L561-14',
#      'articleId': 'LEGIARTI000042648537',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L561-2 (M)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L561-2',
#      'articleId': 'LEGIARTI000042648575',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L561-2 (VD)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L561-2',
#      'articleId': 'LEGIARTI000033582023',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2022-07-01'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L561-20 (V)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L561-20',
#      'articleId': 'LEGIARTI000042648504',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L561-7 (V)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L561-7',
#      'articleId': 'LEGIARTI000042648544',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644810',
#    'cid': 'JORFARTI000042636239',
#    'intOrdre': 2621435,
#    'etat': 'VIGUEUR',
#    'num': '5',
#    'path': '/LEGIARTI000042644810',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648655&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L572-24 (V)">  Art. L572-24</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L572-24 (V)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L572-24',
#      'articleId': 'LEGIARTI000042648655',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644812',
#    'cid': 'JORFARTI000042636240',
#    'intOrdre': 3145722,
#    'etat': 'VIGUEUR',
#    'num': '6',
#    'path': '/LEGIARTI000042644812',
#    'pathTitle': [],
#    'content': '<br/>A créé les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042646494&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L725-4 (M)">  Art. L725-4</a></BLOCKQUOTE></BLOCKQUOTE><br/><p> <br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCode.do?cidTexte=LEGITEXT000006072026&idSectionTA=LEGISCTA000042648658&dateTexte=&categorieLien=id" title="Code monétaire et financier -  Section 3 : Obligations relatives à la lutte co... (VT)">  Sct. Section 3 : Obligations relatives à la lutte contre le blanchiment de capitaux et le financement du terrorisme</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier -  Section 3 : Obligations relatives à la lutte co... (VT)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': '',
#      'articleId': 'LEGISCTA000042648658',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L725-4 (M)',
#      'linkType': 'CREE',
#      'linkOrientation': 'source',
#      'articleNum': 'L725-4',
#      'articleId': 'LEGIARTI000042646494',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644814',
#    'cid': 'JORFARTI000042636241',
#    'intOrdre': 3670009,
#    'etat': 'VIGUEUR',
#    'num': '7',
#    'path': '/LEGIARTI000042644814',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648661&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L745-11-9 (VT)">  Art. L745-11-9</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L745-11-9 (VT)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L745-11-9',
#      'articleId': 'LEGIARTI000042648661',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644816',
#    'cid': 'JORFARTI000042636242',
#    'intOrdre': 4194296,
#    'etat': 'VIGUEUR',
#    'num': '8',
#    'path': '/LEGIARTI000042644816',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042653399&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L745-13 (M)">  Art. L745-13</a>, <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042653352&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L755-13 (M)">  Art. L755-13</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L745-13 (M)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L745-13',
#      'articleId': 'LEGIARTI000042653399',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L755-13 (M)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L755-13',
#      'articleId': 'LEGIARTI000042653352',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644818',
#    'cid': 'JORFARTI000042636243',
#    'intOrdre': 4718583,
#    'etat': 'VIGUEUR',
#    'num': '9',
#    'path': '/LEGIARTI000042644818',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648666&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L765-11-9 (VT)">  Art. L765-11-9</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L765-11-9 (VT)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L765-11-9',
#      'articleId': 'LEGIARTI000042648666',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644820',
#    'cid': 'JORFARTI000042636244',
#    'intOrdre': 5242870,
#    'etat': 'VIGUEUR',
#    'num': '10',
#    'path': '/LEGIARTI000042644820',
#    'pathTitle': [],
#    'content': '<br/>A modifié les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042648671&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L765-13 (M)">  Art. L765-13</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L765-13 (M)',
#      'linkType': 'MODIFIE',
#      'linkOrientation': 'source',
#      'articleNum': 'L765-13',
#      'articleId': 'LEGIARTI000042648671',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644822',
#    'cid': 'JORFARTI000042636245',
#    'intOrdre': 5767157,
#    'etat': 'VIGUEUR',
#    'num': '11',
#    'path': '/LEGIARTI000042644822',
#    'pathTitle': [],
#    'content': '<br/>A créé les dispositions suivantes :<BLOCKQUOTE>- Code monétaire et financier<BLOCKQUOTE><a href="/affichCode.do?cidTexte=LEGITEXT000006072026&idSectionTA=LEGISCTA000042647202&dateTexte=&categorieLien=id" title="Code monétaire et financier -  Section 3 : Obligations relatives à la lutte co... (VT)">  Sct. Section 3 : Obligations relatives à la lutte contre le blanchiment des capitaux et le financement du terrorisme </a>, <a href="/affichCodeArticle.do?cidTexte=LEGITEXT000006072026&idArticle=LEGIARTI000042647204&dateTexte=&categorieLien=id" title="Code monétaire et financier - art. L772-3 (VT)">  Art. L772-3</a></BLOCKQUOTE></BLOCKQUOTE><br/>',
#    'nota': '',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'ENTIEREMENT_MODIF',
#    'lstLienModification': [{'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier -  Section 3 : Obligations relatives à la lutte co... (VT)',
#      'linkType': 'CREE',
#      'linkOrientation': 'source',
#      'articleNum': '',
#      'articleId': 'LEGISCTA000042647202',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'},
#     {'textCid': 'LEGITEXT000006072026',
#      'textTitle': 'Code monétaire et financier - art. L772-3 (VT)',
#      'linkType': 'CREE',
#      'linkOrientation': 'source',
#      'articleNum': 'L772-3',
#      'articleId': 'LEGIARTI000042647204',
#      'natureText': 'CODE',
#      'datePubliTexte': '2999-01-01',
#      'dateSignaTexte': '2999-01-01',
#      'dateDebutCible': '2020-12-11'}],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644824',
#    'cid': 'JORFARTI000042636246',
#    'intOrdre': 6291444,
#    'etat': 'VIGUEUR',
#    'num': '12',
#    'path': '/LEGIARTI000042644824',
#    'pathTitle': [],
#    'content': "<p><br/>Les personnes exerçant les activités définies aux 3° et 4° de l'article L. 54-10-2 du code monétaire et financier avant l'entrée en vigueur de la présente ordonnance bénéficient d'un délai de six mois à compter de sa publication pour s'enregistrer auprès de l'Autorité des marchés financiers dans les conditions définies à l'article L. 54-10-3 du même code.<br/>Les dispositions du 3° de l'article 1er sont applicables aux demandes d'enregistrement déposées auprès de l'Autorité des marchés financiers ou en cours d'examen par celle-ci dans les conditions définies à l'article L. 54-10-3 du code monétaire et financier pour l'exercice des activités définies aux 1° et 2° de l'article L. 54-10-2 du même code à compter de la publication de la présente ordonnance.</p>",
#    'nota': '<p></p>',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'AUTONOME',
#    'lstLienModification': [],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644826',
#    'cid': 'JORFARTI000042636247',
#    'intOrdre': 6815731,
#    'etat': 'VIGUEUR',
#    'num': '13',
#    'path': '/LEGIARTI000042644826',
#    'pathTitle': [],
#    'content': "<p><br/>L'article 12 est applicable en Nouvelle-Calédonie, en Polynésie française et à Wallis-et-Futuna.</p>",
#    'nota': '<p></p>',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'AUTONOME',
#    'lstLienModification': [],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False},
#   {'executionTime': 0,
#    'dereferenced': False,
#    'id': 'LEGIARTI000042644828',
#    'cid': 'JORFARTI000042636248',
#    'intOrdre': 7340018,
#    'etat': 'VIGUEUR',
#    'num': '14',
#    'path': '/LEGIARTI000042644828',
#    'pathTitle': [],
#    'content': "<p><br/>Le Premier ministre, le ministre de l'économie, des finances et de la relance et le ministre des outre-mer sont responsables, chacun en ce qui le concerne, de l'application de la présente ordonnance, qui sera publiée au Journal officiel de la République française.</p>",
#    'nota': '<p></p>',
#    'comporteLiens': False,
#    'comporteLiensSP': False,
#    'modificatorTitle': None,
#    'modificatorCid': None,
#    'modificatorDate': None,
#    'articleVersion': '1.0',
#    'type': 'AUTONOME',
#    'lstLienModification': [],
#    'lstLienCitation': [],
#    'conditionDiffere': None,
#    'historique': None,
#    'surtitre': None,
#    'renvoi': None,
#    'versionLabel': None,
#    'infosComplementaires': None,
#    'infosComplementairesHtml': None,
#    'infosRestructurationBranche': None,
#    'infosRestructurationBrancheHtml': None,
#    'dateDebut': None,
#    'dateFin': None,
#    'notaSectionsAafficher': None,
#    'multipleVersions': False}],
#  'pagePdf': None,
#  'fileName': None,
#  'fileSize': None,
#  'filePath': None}

# %% [markdown]
# ### 2.6 - Consult JORF

# %% [markdown]
# Pour trouver et récup JORF ordonnance
# Exemple: https://www.legifrance.gouv.fr/jorf/id/JORFTEXT000042636234

# %%
def getJOFR(textCid :str): #JORFTEXT000042636234
  url= 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/jorf'
  headers= {'accept': 'application/json',
		'Content-Type': 'application/json',
		'Authorization': 'Bearer ' + access_token}
  data= {"searchedString":"","textCid":textCid}
  response = requests.post( headers =headers, url= url, json= data )
  response_json = response.json()
  return response_json

# %%
getJOFR("JORFTEXT000042636234")

# %% [markdown]
# ### 2.7 - Contenu d'un article /consult/getArticle (Fait)

# %% [markdown]
# Récupère un article par son identifiant (article id)
#
# id : ID unique de la version de l'article pour accéder directement à une version particulière (historique ou active).

# %% [markdown]
# #### Get article and metadata

# %%
def getArticle_metadata(id : str):
  headers= {'accept': 'application/json','Content-Type': 'application/json','Authorization': 'Bearer ' + access_token}
  url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticle'
  data = {"id":id}
  response= requests.post(url=url,  headers=headers, json = data)
  return {"num":  response.json()["article"]['num'],
          "etat": response.json()["article"]['etat'],
         "Text" : response.json()["article"]['texte']}

# %%
getArticle_metadata("LEGIARTI000048844359")
# OK: LEGIARTI000048243369, LEGIARTI000048656110 , LEGIARTI000006812142
# Out:
# {'num': 'L421-4-1',
#  'etat': 'VIGUEUR',
#  'Text': "Les contributions pour l'alimentation du fonds de garantie mentionnées à l'article L. 421-4 sont ainsi définies : 1° La contribution des assurés est assise sur toutes les primes ou cotisations nettes qu'ils versent aux entreprises d'assurance pour l'assurance des risques de responsabilité civile résultant d'accidents causés par les véhicules terrestres à moteur et des remorques ou semi-remorques des véhicules lorsque le risque est situé sur le territoire de la République française. Elle est perçue par les entreprises d'assurance suivant les mêmes règles et sous les mêmes garanties et sanctions que la taxe sur les conventions d'assurance prévue à l'article 991 du code général des impôts. Elle est recouvrée mensuellement par le fonds de garantie ; 2° La contribution des entreprises d'assurance est assise sur toutes les primes ou cotisations nettes qu'elles perçoivent pour l'assurance des risques de responsabilité civile résultant d'accidents causés par les véhicules terrestres à moteur et les remorques ou semi-remorques des véhicules lorsque le risque est situé sur le territoire de la République française. Elle est acquittée par les entreprises d'assurance suivant les mêmes règles et sous les mêmes garanties et sanctions que la taxe sur les conventions d'assurance prévue au même article 991. Elle est recouvrée mensuellement par le fonds de garantie ; 3° (Abrogé) ; 4° (Abrogé) ; 5° La contribution des responsables d'accidents causés par l'utilisation des véhicules définis au 1° du présent article, non bénéficiaires d'une assurance, est assise sur le montant total des indemnités mises à leur charge à titre de réparation des dommages résultant de ces accidents. Sont considérées comme bénéficiaires d'une assurance, au sens du présent article, les personnes dont la responsabilité civile est couverte par un contrat d'assurance dans les conditions prévues à l'article L. 211-1 . Un tel bénéfice ne leur est toutefois acquis, au sens du présent article, que pour la part excédant la franchise prévue éventuellement par leur contrat en application de l'article L. 121-1 . En cas d'instance judiciaire, la décision doit faire apparaître si le responsable est ou non bénéficiaire d'une assurance. La contribution est liquidée et recouvrée par les services de la direction générale des finances publiques, selon les mêmes règles, sous les mêmes garanties et sous les mêmes sanctions qu'en matière de droits d'enregistrement. Elle est perçue sur la notification faite à cette direction par le fonds de garantie. La contribution doit être acquittée dans le délai d'un mois à compter de la réclamation adressée par la direction générale des finances publiques."}

# %% [markdown]
# #### Get content of previous version of an article (function for the 2de column)

# %%
def getArticle_prev_vers(id : str):
  headers= {'accept': 'application/json','Content-Type': 'application/json','Authorization': 'Bearer ' + access_token}
  url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticle'
  data = {"id":id}
  response= requests.post(url=url,  headers=headers, json = data)
  nouvel_id= response.json()['article']['articleVersions'][-2]['id']
  nouveau_data = {"id":nouvel_id}
  response_nouvelle= requests.post(url=url,  headers=headers, json = nouveau_data)
  response_json= response_nouvelle.json()
  return response_json["article"]['texte']

# %%
import requests
def getArticle_prev_vers(id: str):
    headers = {
        'accept': 'application/json',
        'Content-Type': 'application/json',
        'Authorization': 'Bearer ' + access_token
    }
    url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticle'

    try:
        # Requête initiale pour obtenir les versions de l'article
        data = {"id": id}
        response = requests.post(url=url, headers=headers, json=data)

        # Vérification du code de statut HTTP
        if response.status_code != 200:
            return "KO status_code"

        # Extraction des données de l'article
        article = response.json().get("article", {})
        article_versions = article.get("articleVersions", [])

        # Vérification de l'existence d'une version précédente
        if len(article_versions) < 2:
            return "KO version précédente"

        # Récupération de l'ID de la version précédente
        nouvel_id = article_versions[-2].get("id")
        if not nouvel_id:
            return "KO absence ID de la version précédente "

        # Requête pour la version précédente
        nouveau_data = {"id": nouvel_id}
        response_nouvelle = requests.post(url=url, headers=headers, json=nouveau_data)

        # Vérification du code de statut HTTP pour la seconde requête
        if response_nouvelle.status_code != 200:
            return "KO status_code HTTP seconde requête"

        # Extraction des données de la version précédente
        response_json = response_nouvelle.json()
        texte = response_json.get("article", {}).get("texte")

        # Vérification si le texte de l'article existe
        return texte if texte else "KO"

    except Exception as e:
        # Gestion des exceptions (problème de connexion, JSON invalide, etc.)
        print(f"Erreur : {e}")
        return "KO"

# %%
getArticle_prev_vers("LEGIARTI000048844359")
# OK: LEGIARTI000048243369, LEGIARTI000048656110 , LEGIARTI000006812142
# Out:
# "Les contributions pour l'alimentation du fonds de garantie mentionnées à l'article L. 421-4 sont ainsi définies : 1° La contribution des assurés est assise sur toutes les primes ou cotisations nettes qu'ils versent aux entreprises d'assurance pour l'assurance des risques de responsabilité civile résultant d'accidents causés par les véhicules terrestres à moteur et des remorques ou semi-remorques des véhicules lorsque le risque est situé sur le territoire de la République française. Elle est perçue par les entreprises d'assurance suivant les mêmes règles et sous les mêmes garanties et sanctions que la taxe sur les conventions d'assurance prévue à l'article 991 du code général des impôts. Elle est recouvrée mensuellement par le fonds de garantie ; 2° La contribution des entreprises d'assurance est proportionnelle aux primes ou cotisations du dernier exercice, accessoires et rappels compris et annulations déduites, relatives à l'assurance des véhicules terrestres à moteur et des remorques ou semi-remorques des véhicules lorsque le risque est situé sur le territoire de la République française. Elle est acquittée par les entreprises d'assurance suivant les mêmes règles et sous les mêmes garanties et sanctions que la taxe sur les conventions d'assurance prévue au même article 991. Elle est recouvrée mensuellement par le fonds de garantie ; 3° (Abrogé) ; 4° (Abrogé) ; 5° La contribution des responsables d'accidents causés par l'utilisation des véhicules définis au 1° du présent article, non bénéficiaires d'une assurance, est assise sur le montant total des indemnités mises à leur charge à titre de réparation des dommages résultant de ces accidents. Sont considérées comme bénéficiaires d'une assurance, au sens du présent article, les personnes dont la responsabilité civile est couverte par un contrat d'assurance dans les conditions prévues à l'article L. 211-1 . Un tel bénéfice ne leur est toutefois acquis, au sens du présent article, que pour la part excédant la franchise prévue éventuellement par leur contrat en application de l'article L. 121-1 . En cas d'instance judiciaire, la décision doit faire apparaître si le responsable est ou non bénéficiaire d'une assurance. La contribution est liquidée et recouvrée par les services de la direction générale des finances publiques, selon les mêmes règles, sous les mêmes garanties et sous les mêmes sanctions qu'en matière de droits d'enregistrement. Elle est perçue sur la notification faite à cette direction par le fonds de garantie. La contribution doit être acquittée dans le délai d'un mois à compter de la réclamation adressée par la direction générale des finances publiques."

# %% [markdown]
# #### Get content new version of an article (function for the 1srt column)

# %%
def getArticle(id : str):
  headers= {'accept': 'application/json','Content-Type': 'application/json','Authorization': 'Bearer ' + access_token}
  url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticle'
  data = {"id":id}
  response= requests.post(url=url,  headers=headers, json = data)
  return response.json()["article"]['texte']

# %%
getArticle("LEGIARTI000048844359")
# Out:
# "Les contributions pour l'alimentation du fonds de garantie mentionnées à l'article L. 421-4 sont ainsi définies : 1° La contribution des assurés est assise sur toutes les primes ou cotisations nettes qu'ils versent aux entreprises d'assurance pour l'assurance des risques de responsabilité civile résultant d'accidents causés par les véhicules terrestres à moteur et des remorques ou semi-remorques des véhicules lorsque le risque est situé sur le territoire de la République française. Elle est perçue par les entreprises d'assurance suivant les mêmes règles et sous les mêmes garanties et sanctions que la taxe sur les conventions d'assurance prévue à l'article 991 du code général des impôts. Elle est recouvrée mensuellement par le fonds de garantie ; 2° La contribution des entreprises d'assurance est assise sur toutes les primes ou cotisations nettes qu'elles perçoivent pour l'assurance des risques de responsabilité civile résultant d'accidents causés par les véhicules terrestres à moteur et les remorques ou semi-remorques des véhicules lorsque le risque est situé sur le territoire de la République française. Elle est acquittée par les entreprises d'assurance suivant les mêmes règles et sous les mêmes garanties et sanctions que la taxe sur les conventions d'assurance prévue au même article 991. Elle est recouvrée mensuellement par le fonds de garantie ; 3° (Abrogé) ; 4° (Abrogé) ; 5° La contribution des responsables d'accidents causés par l'utilisation des véhicules définis au 1° du présent article, non bénéficiaires d'une assurance, est assise sur le montant total des indemnités mises à leur charge à titre de réparation des dommages résultant de ces accidents. Sont considérées comme bénéficiaires d'une assurance, au sens du présent article, les personnes dont la responsabilité civile est couverte par un contrat d'assurance dans les conditions prévues à l'article L. 211-1 . Un tel bénéfice ne leur est toutefois acquis, au sens du présent article, que pour la part excédant la franchise prévue éventuellement par leur contrat en application de l'article L. 121-1 . En cas d'instance judiciaire, la décision doit faire apparaître si le responsable est ou non bénéficiaire d'une assurance. La contribution est liquidée et recouvrée par les services de la direction générale des finances publiques, selon les mêmes règles, sous les mêmes garanties et sous les mêmes sanctions qu'en matière de droits d'enregistrement. Elle est perçue sur la notification faite à cette direction par le fonds de garantie. La contribution doit être acquittée dans le délai d'un mois à compter de la réclamation adressée par la direction générale des finances publiques."

# %%
import requests

def getArticle(id: str):
    headers = {
        'accept': 'application/json',
        'Content-Type': 'application/json',
        'Authorization': 'Bearer ' + access_token
    }
    url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticle'
    data = {"id": id}

    try:
        response = requests.post(url=url, headers=headers, json=data)
        # Vérification du statut HTTP
        if response.status_code != 200:
            return "KO Status Code"

        # Extraction des données
        article = response.json().get("article", {})

        # Vérification si le texte de l'article est présent
        if "texte" in article:
            return article["texte"]
        else:
            return "KO article pas trouvé"

    except Exception as e:
        # Gestion des exceptions (erreur de connexion, JSON invalide, etc.)
        print(f"Erreur : {e}")
        return "KO autre"

# %% [markdown]
# Requete centrale permet de récupérer une version d'un text de loi en fonction de l'id (voir possibles valeurs ci dessous) et dates de mises en oeuvre.
# Exemples id:
#
# - LEGITEXT000006073984 # code des assurances
#
# - LEGITEXT000006070721 # code civil
#
# - LEGITEXT000005634379 # Code de commerce
#
# - LEGITEXT000006070719 # code pénal
#
# - LEGITEXT000006072026 # cmf

# %% [markdown]
# ### 2.8 - Extrait d'une version d'un texte  /chrono/textCidAndElementCid (Fait - pas utilisé)
#
# Récupère un extrait (section ou article) d'une version spécifique d'un texte à partir des identifiants du texte (textCid) et de l'extrait section ou article: "elementCid"
#
# Remarque : absence de contenu d'article dans la réponse

# %%
def textCidAndElementCid(textCid, elementCid): # text cid: LEGITEXT000006072050 Element Cid LEGIARTI000006901817
  url = "https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/chrono/textCidAndElementCid"
  headers = {
      'accept': 'application/json',
      'Content-Type': 'application/json',
      'Authorization': 'Bearer ' + access_token}
  data = { "textCid": textCid, # code du travail
    "elementCid": elementCid # Article L2262-8
  }
  response = requests.post(url, headers=headers, json= data)
  response_json= response.json()
  return response_json

# %%
# Test 1: "textCid": "LEGITEXT000006070721" Code Civil, "elementCid": "LEGIARTI000038033084" -> NA
# Test 2: "textCid": "LEGITEXT000006070721" Code Civil , "elementCid": "LEGIARTI000006417324" -> NA
# Test 3 : "textCid": "LEGITEXT000006072050" Code du Travail + Article L1221-1 "elementCid": "LEGIARTI000006901817" -> ok
# https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000006900839

# %%
textCidAndElementCid("LEGITEXT000006072050", 'LEGIARTI000006901817')
# Out:
# {'executionTime': 0,
#  'regroupements': [{'title': '2008',
#    'versions': {'2008-05-01': {'dateDebut': 1209600000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'JORFTEXT000000465978': {'title': 'Ordonnance 2007-329 2007-03-12 JORF 13 mars 2007',
#        'id': 'JORFTEXT000000465978',
#        'nature': 'CODE',
#        'dateDebutCible': 32472144000000,
#        'actions': {'CODIFICATION': {'action': 'CODIFICATION',
#          'parents': {'LEGISCTA000006189538': {'name': 'Section 2 : Information et communication.',
#            'id': 'LEGISCTA000006189538',
#            'cid': 'LEGISCTA000006189538',
#            'cidText': 'LEGITEXT000006072050',
#            'nature': 'CODE',
#            'dateDebut': 1209600000000,
#            'articlesCibles': {'LEGIARTI000006901817': {'name': 'L2262-8',
#              'id': 'LEGIARTI000006901817',
#              'cid': 'LEGIARTI000006901817',
#              'idParent': 'LEGISCTA000006189538',
#              'cidParent': 'LEGISCTA000006189538',
#              'cidText': 'LEGITEXT000006072050',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072050/LEGISCTA000006112874/LEGISCTA000006132331/LEGISCTA000006145398/LEGISCTA000006160736/LEGISCTA000006177939/LEGISCTA000006189538/LEGIARTI000006901817',
#              'dateDebut': 1209600000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}}},
#    'detailLoaded': True}],
#  'datePublication': '2999-01-01T00:00:00.000+0000'}

# %% [markdown]
# ### 2.9 - Récupère une version (plage de dates) d'un texte (textCid) et version en vigueur (date) (Fait)

# %% [markdown]
# Exemple:
#
# - Consulter le texte spécifié par textCid ("LEGITEXT000006070721").
#
# - Voir les versions de ce texte entre 2015 et 2023

# %% [markdown]
# #### 2.9.1 - Test function output status code and json file keys

# %%
def get_text_modif_byDateslot_textCid_test(textCid, startYear, endYear): #LEGITEXT000006073984 code des assurances
  headers = { 'accept': 'application/json', 'Content-Type': 'application/json', 'Authorization': 'Bearer ' + access_token}
  data = {  "endYear": endYear,  #"dateConsult": "2021-04-15",
  "startYear": startYear,
  "textCid": textCid  }
  url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/chrono/textCid'
  response = requests.post(url, headers=headers, json=data)
  response_json= response.json()
  return {"status code : ": print(response),
  "keys : ": response_json.keys()}

# %%
get_text_modif_byDateslot_textCid_test(textCid= "LEGITEXT000006072026",
                                  startYear= "2019",
                                  endYear= "2021" )
# Out:
# <Response [200]>
# {'status code : ': None,
#  'keys : ': dict_keys(['executionTime', 'regroupements', 'datePublication'])}

# %% [markdown]
# #### 2.9.2 - Central Function to extract code content

# %%
def get_text_modif_byDateslot_textCid_extract_content(textCid, startYear, endYear): #LEGITEXT000006073984 code des assurances
  headers = { 'accept': 'application/json', 'Content-Type': 'application/json', 'Authorization': 'Bearer ' + access_token}
  data = {  "endYear": endYear,  #"dateConsult": "2021-04-15",
  "startYear": startYear,
  "textCid": textCid  }
  url = 'https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/chrono/textCid'
  response = requests.post(url, headers=headers, json=data)
  response_json= response.json()
  return  response_json

# %%
data_json_2_2_3 = get_text_modif_byDateslot_textCid_extract_content(textCid= "LEGITEXT000006072026",
                                  startYear= "2019",
                                  endYear= "2021")

# %%
data_json_2_2_3
# Out:
# {'executionTime': 186,
#  'regroupements': [{'title': '2222',
#    'versions': {'2222-02-22': {'dateDebut': 7956835200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2026',
#    'versions': {'2026-07-01': {'dateDebut': 1782864000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2026-01-01': {'dateDebut': 1767225600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2025',
#    'versions': {'2025-03-14': {'dateDebut': 1741910400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2025-02-01': {'dateDebut': 1738368000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2025-01-01': {'dateDebut': 1735689600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2024',
#    'versions': {'2024-12-30': {'dateDebut': 1735516800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-12-25': {'dateDebut': 1735084800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-12-06': {'dateDebut': 1733443200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-10-24': {'dateDebut': 1729728000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-10-18': {'dateDebut': 1729209600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-07-27': {'dateDebut': 1722038400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-07-08': {'dateDebut': 1720396800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-07-05': {'dateDebut': 1720137600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-07-01': {'dateDebut': 1719792000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-06-17': {'dateDebut': 1718582400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-06-15': {'dateDebut': 1718409600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-05-01': {'dateDebut': 1714521600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-04-24': {'dateDebut': 1713916800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-04-17': {'dateDebut': 1713312000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-04-10': {'dateDebut': 1712707200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-03-02': {'dateDebut': 1709337600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-03-01': {'dateDebut': 1709251200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-01-17': {'dateDebut': 1705449600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-01-01': {'dateDebut': 1704067200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2023',
#    'versions': {'2023-12-31': {'dateDebut': 1703980800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-12-30': {'dateDebut': 1703894400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-12-08': {'dateDebut': 1701993600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-12-01': {'dateDebut': 1701388800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-10-26': {'dateDebut': 1698278400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-10-25': {'dateDebut': 1698192000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-10-15': {'dateDebut': 1697328000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-10-01': {'dateDebut': 1696118400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-09-01': {'dateDebut': 1693526400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-07-22': {'dateDebut': 1689984000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-07-20': {'dateDebut': 1689811200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-07-17': {'dateDebut': 1689552000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-07-15': {'dateDebut': 1689379200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-06-11': {'dateDebut': 1686441600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-06-03': {'dateDebut': 1685750400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-05-26': {'dateDebut': 1685059200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-05-17': {'dateDebut': 1684281600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-05-07': {'dateDebut': 1683417600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-03-11': {'dateDebut': 1678492800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-02-23': {'dateDebut': 1677110400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-02-19': {'dateDebut': 1676764800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-02-06': {'dateDebut': 1675641600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-02-01': {'dateDebut': 1675209600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-01-01': {'dateDebut': 1672531200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2022',
#    'versions': {'2022-12-21': {'dateDebut': 1671580800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-11-27': {'dateDebut': 1669507200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-11-25': {'dateDebut': 1669334400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-09-16': {'dateDebut': 1663286400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-09-01': {'dateDebut': 1661990400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-08-18': {'dateDebut': 1660780800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-07-08': {'dateDebut': 1657238400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-07-01': {'dateDebut': 1656633600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-06-18': {'dateDebut': 1655510400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-06-13': {'dateDebut': 1655078400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-04-22': {'dateDebut': 1650585600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-04-01': {'dateDebut': 1648771200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-28': {'dateDebut': 1646006400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-26': {'dateDebut': 1645833600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-23': {'dateDebut': 1645574400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-18': {'dateDebut': 1645142400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-07': {'dateDebut': 1644192000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-04': {'dateDebut': 1643932800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-01-31': {'dateDebut': 1643587200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-01-01': {'dateDebut': 1640995200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2021',
#    'versions': {'2021-12-27': {'dateDebut': 1640563200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000044565398': {'title': 'LOI n°2021-1774 du 24 décembre 2021 - art. 2',
#        'id': 'LEGIARTI000044565398',
#        'nature': 'CODE',
#        'dateDebutCible': 1640563200000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000020866615': {'name': 'Sous-section 1 : Droit au compte',
#            'id': 'LEGISCTA000020866615',
#            'cid': 'LEGISCTA000020861267',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1257033600000,
#            'articlesCibles': {'LEGIARTI000044605348': {'name': 'L312-1',
#              'id': 'LEGIARTI000044605348',
#              'cid': 'LEGIARTI000006652033',
#              'idParent': 'LEGISCTA000020866615',
#              'cidParent': 'LEGISCTA000020861267',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123907/LEGISCTA000006139955/LEGISCTA000006154410/LEGISCTA000006170365/LEGISCTA000020861267/LEGIARTI000006652033',
#              'dateDebut': 1640563200000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044565414': {'title': 'LOI n°2021-1774 du 24 décembre 2021 - art. 17 (V)',
#        'id': 'LEGIARTI000044565414',
#        'nature': 'CODE',
#        'dateDebutCible': 1640563200000,
#        'actions': {'CREATION': {'action': 'CREATION',
#          'parents': {'LEGISCTA000006184917': {'name': 'Sous-section 2 : Dispositions particulières aux sociétés de gestion de portefeuille',
#            'id': 'LEGISCTA000006184917',
#            'cid': 'LEGISCTA000006184917',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1193875200000,
#            'articlesCibles': {'LEGIARTI000044566877': {'name': 'L533-22-2-4',
#              'id': 'LEGIARTI000044566877',
#              'cid': 'LEGIARTI000044566877',
#              'idParent': 'LEGISCTA000006184917',
#              'cidParent': 'LEGISCTA000006184917',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140119/LEGISCTA000006154697/LEGISCTA000006170648/LEGISCTA000006184917/LEGIARTI000044566877',
#              'dateDebut': 1640563200000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}},
#     '2021-12-25': {'dateDebut': 1640390400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000044606316': {'title': 'Décret n°2021-1757 du 22 décembre 2021 - art. 1',
#        'id': 'LEGIARTI000044606316',
#        'nature': 'CODE',
#        'dateDebutCible': 1640390400000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000036821754': {'name': 'Sous-section 2 : Pouvoirs et prérogatives',
#            'id': 'LEGISCTA000036821754',
#            'cid': 'LEGISCTA000036821713',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1538352000000,
#            'articlesCibles': {'LEGIARTI000044619935': {'name': 'R561-36',
#              'id': 'LEGIARTI000044619935',
#              'cid': 'LEGIARTI000021019772',
#              'idParent': 'LEGISCTA000036821754',
#              'cidParent': 'LEGISCTA000036821713',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006100807/LEGISCTA000006123547/LEGISCTA000006139674/LEGISCTA000019266650/LEGISCTA000021019764/LEGISCTA000036821713/LEGIARTI000021019772',
#              'dateDebut': 1640390400000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044606318': {'title': 'Décret n°2021-1757 du 22 décembre 2021 - art. 2',
#        'id': 'LEGIARTI000044606318',
#        'nature': 'CODE',
#        'dateDebutCible': 1640390400000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006169843': {'name': 'Section 7 : Obligations relatives à la lutte contre le blanchiment des capitaux et le financement des activités terroristes',
#            'id': 'LEGISCTA000006169843',
#            'cid': 'LEGISCTA000006169843',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1176422400000,
#            'articlesCibles': {'LEGIARTI000044619982': {'name': 'R745-10',
#              'id': 'LEGIARTI000044619982',
#              'cid': 'LEGIARTI000006690873',
#              'idParent': 'LEGISCTA000006169843',
#              'cidParent': 'LEGISCTA000006169843',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006100807/LEGISCTA000006123615/LEGISCTA000006139686/LEGISCTA000006153829/LEGISCTA000006169843/LEGIARTI000006690873',
#              'dateDebut': 1640390400000,
#              'dateFin': 1645833600000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000006169844': {'name': 'Section 6 : Obligations relatives à la lutte contre le blanchiment des capitaux et le financement des activités terroristes',
#            'id': 'LEGISCTA000006169844',
#            'cid': 'LEGISCTA000006169844',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1176422400000,
#            'articlesCibles': {'LEGIARTI000044619958': {'name': 'R755-10',
#              'id': 'LEGIARTI000044619958',
#              'cid': 'LEGIARTI000006691604',
#              'idParent': 'LEGISCTA000006169844',
#              'cidParent': 'LEGISCTA000006169844',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006100807/LEGISCTA000006123615/LEGISCTA000006139688/LEGISCTA000006153835/LEGISCTA000006169844/LEGIARTI000006691604',
#              'dateDebut': 1640390400000,
#              'dateFin': 1645833600000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000006169845': {'name': 'Section 6 : Obligations relatives à la lutte contre le blanchiment des capitaux et le financement des activités terroristes',
#            'id': 'LEGISCTA000006169845',
#            'cid': 'LEGISCTA000006169845',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1176422400000,
#            'articlesCibles': {'LEGIARTI000044619942': {'name': 'R765-10',
#              'id': 'LEGIARTI000044619942',
#              'cid': 'LEGIARTI000006691636',
#              'idParent': 'LEGISCTA000006169845',
#              'cidParent': 'LEGISCTA000006169845',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006100807/LEGISCTA000006123615/LEGISCTA000006139695/LEGISCTA000006153841/LEGISCTA000006169845/LEGIARTI000006691636',
#              'dateDebut': 1640390400000,
#              'dateFin': 1645833600000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}},
#     '2021-12-24': {'dateDebut': 1640304000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'JORFTEXT000000422094': {'title': 'LOI n° 2003-591 du 2 juillet 2003',
#        'id': 'JORFTEXT000000422094',
#        'nature': 'CODE',
#        'dateDebutCible': 32472144000000,
#        'actions': {'CODIFICATION': {'action': 'CODIFICATION',
#          'parents': {'LEGISCTA000006184941': {'name': 'Sous-section 5 : Sanctions',
#            'id': 'LEGISCTA000006184941',
#            'cid': 'LEGISCTA000006184941',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1115424000000,
#            'articlesCibles': {'LEGIARTI000044564406': {'name': 'L621-17',
#              'id': 'LEGIARTI000044564406',
#              'cid': 'LEGIARTI000006660400',
#              'idParent': 'LEGISCTA000006184941',
#              'cidParent': 'LEGISCTA000006184941',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006124085/LEGISCTA000006140166/LEGISCTA000006154725/LEGISCTA000006170689/LEGISCTA000006184941/LEGIARTI000006660400',
#              'dateDebut': 1640304000000,
#              'dateFin': 1735516800000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'JORFTEXT000000574488': {'title': "Rapport relatif à l'ordonnance n° 2000-1223 du 14 décembre 2000",
#        'id': 'JORFTEXT000000574488',
#        'nature': 'CODE',
#        'dateDebutCible': 32472144000000,
#        'actions': {'CODIFICATION': {'action': 'CODIFICATION',
#          'parents': {'LEGISCTA000006184941': {'name': 'Sous-section 5 : Sanctions',
#            'id': 'LEGISCTA000006184941',
#            'cid': 'LEGISCTA000006184941',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1115424000000,
#            'articlesCibles': {'LEGIARTI000044564406': {'name': 'L621-17',
#              'id': 'LEGIARTI000044564406',
#              'cid': 'LEGIARTI000006660400',
#              'idParent': 'LEGISCTA000006184941',
#              'cidParent': 'LEGISCTA000006184941',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006124085/LEGISCTA000006140166/LEGISCTA000006154725/LEGISCTA000006170689/LEGISCTA000006184941/LEGIARTI000006660400',
#              'dateDebut': 1640304000000,
#              'dateFin': 1735516800000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044549001': {'title': 'LOI n°2021-1729 du 22 décembre 2021 - art. 60',
#        'id': 'LEGIARTI000044549001',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006170893': {'name': 'Section 6 : Obligations relatives à la lutte contre le blanchiment de capitaux',
#            'id': 'LEGISCTA000006170893',
#            'cid': 'LEGISCTA000006170893',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1093046400000,
#            'articlesCibles': {'LEGIARTI000044570494': {'name': 'L745-13',
#              'id': 'LEGIARTI000044570494',
#              'cid': 'LEGIARTI000006665085',
#              'idParent': 'LEGISCTA000006170893',
#              'cidParent': 'LEGISCTA000006170893',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006124131/LEGISCTA000006140189/LEGISCTA000006154751/LEGISCTA000006170893/LEGIARTI000006665085',
#              'dateDebut': 1640304000000,
#              'dateFin': 1645833600000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000006170898': {'name': 'Section 6 : Obligations relatives à la lutte contre le blanchiment de capitaux',
#            'id': 'LEGISCTA000006170898',
#            'cid': 'LEGISCTA000006170898',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1093046400000,
#            'articlesCibles': {'LEGIARTI000044570419': {'name': 'L755-13',
#              'id': 'LEGIARTI000044570419',
#              'cid': 'LEGIARTI000006666329',
#              'idParent': 'LEGISCTA000006170898',
#              'cidParent': 'LEGISCTA000006170898',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006124131/LEGISCTA000006140196/LEGISCTA000006154758/LEGISCTA000006170898/LEGIARTI000006666329',
#              'dateDebut': 1640304000000,
#              'dateFin': 1645833600000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000006170932': {'name': 'Section 6 : Obligations relatives à la lutte contre le blanchiment de capitaux',
#            'id': 'LEGISCTA000006170932',
#            'cid': 'LEGISCTA000006170932',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1115424000000,
#            'articlesCibles': {'LEGIARTI000044570344': {'name': 'L765-13',
#              'id': 'LEGIARTI000044570344',
#              'cid': 'LEGIARTI000006667560',
#              'idParent': 'LEGISCTA000006170932',
#              'cidParent': 'LEGISCTA000006170932',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006124131/LEGISCTA000006140208/LEGISCTA000006154769/LEGISCTA000006170932/LEGIARTI000006667560',
#              'dateDebut': 1640304000000,
#              'dateFin': 1645833600000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550334': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 7',
#        'id': 'LEGIARTI000044550334',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000020148291': {'name': "Chapitre Ier : Définitions et champ d'application",
#            'id': 'LEGISCTA000020148291',
#            'cid': 'LEGISCTA000006154468',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1238544000000,
#            'articlesCibles': {'LEGIARTI000044563789': {'name': 'L411-2',
#              'id': 'LEGIARTI000044563789',
#              'cid': 'LEGIARTI000006652322',
#              'idParent': 'LEGISCTA000020148291',
#              'cidParent': 'LEGISCTA000006154468',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123910/LEGISCTA000006139980/LEGISCTA000006154468/LEGIARTI000006652322',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550336': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 8',
#        'id': 'LEGIARTI000044550336',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000020148276': {'name': 'Chapitre II : Dispositions générales',
#            'id': 'LEGISCTA000020148276',
#            'cid': 'LEGISCTA000006154469',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1238544000000,
#            'articlesCibles': {'LEGIARTI000044563805': {'name': 'L412-1',
#              'id': 'LEGIARTI000044563805',
#              'cid': 'LEGIARTI000006652325',
#              'idParent': 'LEGISCTA000020148276',
#              'cidParent': 'LEGISCTA000006154469',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123910/LEGISCTA000006139980/LEGISCTA000006154469/LEGIARTI000006652325',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550338': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 9',
#        'id': 'LEGIARTI000044550338',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006170507': {'name': 'Section 2 : Interdictions',
#            'id': 'LEGISCTA000006170507',
#            'cid': 'LEGISCTA000006170507',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 978307200000,
#            'articlesCibles': {'LEGIARTI000044563826': {'name': 'L511-6',
#              'id': 'LEGIARTI000044563826',
#              'cid': 'LEGIARTI000006654300',
#              'idParent': 'LEGISCTA000006170507',
#              'cidParent': 'LEGISCTA000006170507',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140044/LEGISCTA000006154608/LEGISCTA000006170507/LEGIARTI000006654300',
#              'dateDebut': 1640304000000,
#              'dateFin': 1704067200000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550340': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 10',
#        'id': 'LEGIARTI000044550340',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000022962764': {'name': "Section 1 :  Définitions et obligation d'immatriculation",
#            'id': 'LEGISCTA000022962764',
#            'cid': 'LEGISCTA000022952742',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1287878400000,
#            'articlesCibles': {'LEGIARTI000044563888': {'name': 'L519-1',
#              'id': 'LEGIARTI000044563888',
#              'cid': 'LEGIARTI000006657007',
#              'idParent': 'LEGISCTA000022962764',
#              'cidParent': 'LEGISCTA000022952742',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140044/LEGISCTA000006154694/LEGISCTA000022952742/LEGIARTI000006657007',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550342': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 11',
#        'id': 'LEGIARTI000044550342',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000022962764': {'name': "Section 1 :  Définitions et obligation d'immatriculation",
#            'id': 'LEGISCTA000022962764',
#            'cid': 'LEGISCTA000022952742',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1287878400000,
#            'articlesCibles': {'LEGIARTI000044563901': {'name': 'L519-2',
#              'id': 'LEGIARTI000044563901',
#              'cid': 'LEGIARTI000006657008',
#              'idParent': 'LEGISCTA000022962764',
#              'cidParent': 'LEGISCTA000022952742',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140044/LEGISCTA000006154694/LEGISCTA000022952742/LEGIARTI000006657008',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550344': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 12',
#        'id': 'LEGIARTI000044550344',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000022962764': {'name': "Section 1 :  Définitions et obligation d'immatriculation",
#            'id': 'LEGISCTA000022962764',
#            'cid': 'LEGISCTA000022952742',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1287878400000,
#            'articlesCibles': {'LEGIARTI000044563911': {'name': 'L519-3-2',
#              'id': 'LEGIARTI000044563911',
#              'cid': 'LEGIARTI000022952788',
#              'idParent': 'LEGISCTA000022962764',
#              'cidParent': 'LEGISCTA000022952742',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140044/LEGISCTA000006154694/LEGISCTA000022952742/LEGIARTI000022952788',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550346': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 13',
#        'id': 'LEGIARTI000044550346',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000022962856': {'name': "Section 2 : Autres conditions d'accès et d'exercice",
#            'id': 'LEGISCTA000022962856',
#            'cid': 'LEGISCTA000022952802',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1287878400000,
#            'articlesCibles': {'LEGIARTI000044563924': {'name': 'L519-3-4',
#              'id': 'LEGIARTI000044563924',
#              'cid': 'LEGIARTI000022952838',
#              'idParent': 'LEGISCTA000022962856',
#              'cidParent': 'LEGISCTA000022952802',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140044/LEGISCTA000006154694/LEGISCTA000022952802/LEGIARTI000022952838',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550348': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 14',
#        'id': 'LEGIARTI000044550348',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000022962848': {'name': 'Section 3 : Règles de bonne conduite',
#            'id': 'LEGISCTA000022962848',
#            'cid': 'LEGISCTA000022952851',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1287878400000,
#            'articlesCibles': {'LEGIARTI000044563931': {'name': 'L519-4-2',
#              'id': 'LEGIARTI000044563931',
#              'cid': 'LEGIARTI000022953108',
#              'idParent': 'LEGISCTA000022962848',
#              'cidParent': 'LEGISCTA000022952851',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140044/LEGISCTA000006154694/LEGISCTA000022952851/LEGIARTI000022953108',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550350': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 15',
#        'id': 'LEGIARTI000044550350',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000035042854': {'name': "Section 1 : Dispositions générales applicables aux prestataires de services d'investissement",
#            'id': 'LEGISCTA000035042854',
#            'cid': 'LEGISCTA000006170638',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1514937600000,
#            'articlesCibles': {'LEGIARTI000044563936': {'name': 'L531-2',
#              'id': 'LEGIARTI000044563936',
#              'cid': 'LEGIARTI000006657087',
#              'idParent': 'LEGISCTA000035042854',
#              'cidParent': 'LEGISCTA000006170638',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140119/LEGISCTA000006154695/LEGISCTA000006170638/LEGIARTI000006657087',
#              'dateDebut': 1640304000000,
#              'dateFin': 1646006400000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550352': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 16',
#        'id': 'LEGIARTI000044550352',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000038611497': {'name': 'Section 4 : Règles spécifiques concernant les entreprises de pays tiers',
#            'id': 'LEGISCTA000038611497',
#            'cid': 'LEGISCTA000032757156',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1558656000000,
#            'articlesCibles': {'LEGIARTI000044563953': {'name': 'L532-50',
#              'id': 'LEGIARTI000044563953',
#              'cid': 'LEGIARTI000032757193',
#              'idParent': 'LEGISCTA000038611497',
#              'cidParent': 'LEGISCTA000032757156',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140119/LEGISCTA000006154696/LEGISCTA000032757156/LEGIARTI000032757193',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550354': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 17',
#        'id': 'LEGIARTI000044550354',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'ABROGATION': {'action': 'ABROGATION',
#          'parents': {'LEGISCTA000029025635': {'name': "Sous-section 3 : Dispositions particulières aux prestataires de services d'investissement qui réalisent des offres de titres financiers au moyen d'un site internet",
#            'id': 'LEGISCTA000029025635',
#            'cid': 'LEGISCTA000029011963',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1412121600000,
#            'articlesCibles': {'LEGIARTI000029011972': {'name': 'L533-22-3',
#              'id': 'LEGIARTI000029011972',
#              'cid': 'LEGIARTI000029011965',
#              'idParent': 'LEGISCTA000029025635',
#              'cidParent': 'LEGISCTA000029011963',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140119/LEGISCTA000006154697/LEGISCTA000006170648/LEGISCTA000029011963/LEGIARTI000029011965',
#              'dateDebut': 1412121600000,
#              'dateFin': 1640304000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550356': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 18',
#        'id': 'LEGIARTI000044550356',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000022962952': {'name': 'Chapitre VI : Immatriculation unique \r\n\r\n',
#            'id': 'LEGISCTA000022962952',
#            'cid': 'LEGISCTA000022954073',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1287878400000,
#            'articlesCibles': {'LEGIARTI000044564003': {'name': 'L546-1',
#              'id': 'LEGIARTI000044564003',
#              'cid': 'LEGIARTI000022954075',
#              'idParent': 'LEGISCTA000022962952',
#              'cidParent': 'LEGISCTA000022954073',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000022954073/LEGIARTI000022954075',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000044550358': {'title': 'Ordonnance n°2021-1735 du 22 décembre 2021 - art. 19',
#        'id': 'LEGIARTI000044550358',
#        'nature': 'CODE',
#        'dateDebutCible': 1640304000000,
#        'actions': {'ABROGATION': {'action': 'ABROGATION',
#          'parents': {'LEGISCTA000029025592': {'name': 'Chapitre VII : Les conseillers en investissements participatifs',
#            'id': 'LEGISCTA000029025592',
#            'cid': 'LEGISCTA000029011317',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1412121600000,
#            'articlesCibles': {},
#            'sectionsCibles': {'LEGISCTA000035043425': {'name': "Section 2 : Conditions d'accès à l'activité et règles d'organisation",
#              'id': 'LEGISCTA000035043425',
#              'cid': 'LEGISCTA000029011330',
#              'idParent': 'LEGISCTA000029025592',
#              'cidParent': 'LEGISCTA000029011317',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000},
#             'LEGISCTA000035043437': {'name': 'Section 1 : Définition',
#              'id': 'LEGISCTA000035043437',
#              'cid': 'LEGISCTA000029011320',
#              'idParent': 'LEGISCTA000029025592',
#              'cidParent': 'LEGISCTA000029011317',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011320',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000},
#             'LEGISCTA000035043463': {'name': 'Section 3 : Règles de bonne conduite',
#              'id': 'LEGISCTA000035043463',
#              'cid': 'LEGISCTA000029011350',
#              'idParent': 'LEGISCTA000029025592',
#              'cidParent': 'LEGISCTA000029011317',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011350',
#              'dateDebut': 1498608000000,
#              'dateFin': 1640304000000}},
#            'texteCible': None},
#           'LEGISCTA000035016850': {'name': "Sous-section 1 : Conditions d'accès à l'activité",
#            'id': 'LEGISCTA000035016850',
#            'cid': 'LEGISCTA000035016847',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1514937600000,
#            'articlesCibles': {'LEGIARTI000035017346': {'name': 'L547-4-1',
#              'id': 'LEGIARTI000035017346',
#              'cid': 'LEGIARTI000035017307',
#              'idParent': 'LEGISCTA000035016850',
#              'cidParent': 'LEGISCTA000035016847',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330/LEGISCTA000035016847/LEGIARTI000035017307',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000},
#             'LEGIARTI000035017427': {'name': 'L547-5-1',
#              'id': 'LEGIARTI000035017427',
#              'cid': 'LEGIARTI000035017427',
#              'idParent': 'LEGISCTA000035016850',
#              'cidParent': 'LEGISCTA000035016847',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330/LEGISCTA000035016847/LEGIARTI000035017427',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000},
#             'LEGIARTI000035043439': {'name': 'L547-7',
#              'id': 'LEGIARTI000035043439',
#              'cid': 'LEGIARTI000029011346',
#              'idParent': 'LEGISCTA000035016850',
#              'cidParent': 'LEGISCTA000035016847',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330/LEGISCTA000035016847/LEGIARTI000029011346',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000035017555': {'name': "Sous-section 2 : Règles d'organisation",
#            'id': 'LEGISCTA000035017555',
#            'cid': 'LEGISCTA000035017555',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1514937600000,
#            'articlesCibles': {'LEGIARTI000035043467': {'name': 'L547-8',
#              'id': 'LEGIARTI000035043467',
#              'cid': 'LEGIARTI000029011348',
#              'idParent': 'LEGISCTA000035017555',
#              'cidParent': 'LEGISCTA000035017555',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330/LEGISCTA000035017555/LEGIARTI000029011348',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000035043425': {'name': "Section 2 : Conditions d'accès à l'activité et règles d'organisation",
#            'id': 'LEGISCTA000035043425',
#            'cid': 'LEGISCTA000029011330',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1514937600000,
#            'articlesCibles': {},
#            'sectionsCibles': {'LEGISCTA000035016850': {'name': "Sous-section 1 : Conditions d'accès à l'activité",
#              'id': 'LEGISCTA000035016850',
#              'cid': 'LEGISCTA000035016847',
#              'idParent': 'LEGISCTA000035043425',
#              'cidParent': 'LEGISCTA000029011330',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330/LEGISCTA000035016847',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000},
#             'LEGISCTA000035017555': {'name': "Sous-section 2 : Règles d'organisation",
#              'id': 'LEGISCTA000035017555',
#              'cid': 'LEGISCTA000035017555',
#              'idParent': 'LEGISCTA000035043425',
#              'cidParent': 'LEGISCTA000029011330',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011330/LEGISCTA000035017555',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000}},
#            'texteCible': None},
#           'LEGISCTA000035043463': {'name': 'Section 3 : Règles de bonne conduite',
#            'id': 'LEGISCTA000035043463',
#            'cid': 'LEGISCTA000029011350',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1498608000000,
#            'articlesCibles': {'LEGIARTI000035017735': {'name': 'L547-10',
#              'id': 'LEGIARTI000035017735',
#              'cid': 'LEGIARTI000035017727',
#              'idParent': 'LEGISCTA000035043463',
#              'cidParent': 'LEGISCTA000029011350',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011350/LEGIARTI000035017727',
#              'dateDebut': 1514937600000,
#              'dateFin': 1640304000000},
#             'LEGIARTI000039260751': {'name': 'L547-11',
#              'id': 'LEGIARTI000039260751',
#              'cid': 'LEGIARTI000035017729',
#              'idParent': 'LEGISCTA000035043463',
#              'cidParent': 'LEGISCTA000029011350',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011350/LEGIARTI000035017729',
#              'dateDebut': 1571788800000,
#              'dateFin': 1640304000000},
#             'LEGIARTI000039260755': {'name': 'L547-9',
#              'id': 'LEGIARTI000039260755',
#              'cid': 'LEGIARTI000029011352',
#              'idParent': 'LEGISCTA000035043463',
#              'cidParent': 'LEGISCTA000029011350',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGISCTA000029011350/LEGIARTI000029011352',
#              'dateDebut': 1571788800000,
#              'dateFin': 1640304000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}},
#         'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006140127': {'name': 'Titre IV : Autres prestataires de services',
#            'id': 'LEGISCTA000006140127',
#            'cid': 'LEGISCTA000006140127',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1059782400000,
#            'articlesCibles': {},
#            'sectionsCibles': {'LEGISCTA000044564087': {'name': 'Chapitre VII : Prestataires de services de financement participatif',
#              'id': 'LEGISCTA000044564087',
#              'cid': 'LEGISCTA000029011317',
#              'idParent': 'LEGISCTA000006140127',
#              'cidParent': 'LEGISCTA000006140127',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000}},
#            'texteCible': None},
#           'LEGISCTA000044564087': {'name': 'Chapitre VII : Prestataires de services de financement participatif',
#            'id': 'LEGISCTA000044564087',
#            'cid': 'LEGISCTA000029011317',
#            'cidText': 'LEGITEXT000006072026',
#            'nature': 'CODE',
#            'dateDebut': 1640304000000,
#            'articlesCibles': {'LEGIARTI000044564042': {'name': 'L547-6',
#              'id': 'LEGIARTI000044564042',
#              'cid': 'LEGIARTI000029011344',
#              'idParent': 'LEGISCTA000044564087',
#              'cidParent': 'LEGISCTA000029011317',
#              'cidText': 'LEGITEXT000006072026',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072026/LEGISCTA000006101336/LEGISCTA000006123943/LEGISCTA000006140127/LEGISCTA000029011317/LEGIARTI000029011344',
#              'dateDebut': 1640304000000,
#              'dateFin': 32472144000000},
# ...
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-06-29': {'dateDebut': 1214697600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-06-19': {'dateDebut': 1213833600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-06-15': {'dateDebut': 1213488000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-06-13': {'dateDebut': 1213315200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-06-01': {'dateDebut': 1212278400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-05-29': {'dateDebut': 1212019200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-05-25': {'dateDebut': 1211673600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-05-16': {'dateDebut': 1210896000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-05-12': {'dateDebut': 1210550400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-05-01': {'dateDebut': 1209600000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-04-24': {'dateDebut': 1208995200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-02-24': {'dateDebut': 1203811200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-01-05': {'dateDebut': 1199491200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2008-01-01': {'dateDebut': 1199145600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2007',
#    'versions': {'2007-12-23': {'dateDebut': 1198368000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-12-19': {'dateDebut': 1198022400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-12-02': {'dateDebut': 1196553600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-11-22': {'dateDebut': 1195689600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-11-21': {'dateDebut': 1195603200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-11-01': {'dateDebut': 1193875200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-10-30': {'dateDebut': 1193702400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-10-18': {'dateDebut': 1192665600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-09-30': {'dateDebut': 1191110400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-08-12': {'dateDebut': 1186876800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-08-10': {'dateDebut': 1186704000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-07-01': {'dateDebut': 1183248000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-06-15': {'dateDebut': 1181865600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-06-01': {'dateDebut': 1180656000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-05-17': {'dateDebut': 1179360000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-05-16': {'dateDebut': 1179273600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-05-10': {'dateDebut': 1178755200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-04-20': {'dateDebut': 1177027200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-04-19': {'dateDebut': 1176940800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-04-13': {'dateDebut': 1176422400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-04-12': {'dateDebut': 1176336000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-03-28': {'dateDebut': 1175040000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-03-27': {'dateDebut': 1174953600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-03-14': {'dateDebut': 1173830400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-03-07': {'dateDebut': 1173225600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-03-06': {'dateDebut': 1173139200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-03-01': {'dateDebut': 1172707200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-02-28': {'dateDebut': 1172620800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-02-22': {'dateDebut': 1172102400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-02-21': {'dateDebut': 1172016000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-01-20': {'dateDebut': 1169251200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2007-01-01': {'dateDebut': 1167609600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2006',
#    'versions': {'2006-12-31': {'dateDebut': 1167523200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-12-30': {'dateDebut': 1167436800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-12-27': {'dateDebut': 1167177600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-12-23': {'dateDebut': 1166832000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-12-22': {'dateDebut': 1166745600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-12-08': {'dateDebut': 1165536000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-12-05': {'dateDebut': 1165276800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-11-22': {'dateDebut': 1164153600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-10-05': {'dateDebut': 1160006400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-09-30': {'dateDebut': 1159574400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-09-07': {'dateDebut': 1157587200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-09-06': {'dateDebut': 1157500800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-08-01': {'dateDebut': 1154390400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-07-30': {'dateDebut': 1154217600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-07-29': {'dateDebut': 1154131200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-07-25': {'dateDebut': 1153785600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-07-09': {'dateDebut': 1152403200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-07-01': {'dateDebut': 1151712000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-06-27': {'dateDebut': 1151366400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-06-16': {'dateDebut': 1150416000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-05-25': {'dateDebut': 1148515200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-05-18': {'dateDebut': 1147910400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-05-11': {'dateDebut': 1147305600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-04-19': {'dateDebut': 1145404800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-04-01': {'dateDebut': 1143849600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-03-24': {'dateDebut': 1143158400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-03-05': {'dateDebut': 1141516800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-01-24': {'dateDebut': 1138060800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-01-20': {'dateDebut': 1137715200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-01-08': {'dateDebut': 1136678400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-01-06': {'dateDebut': 1136505600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-01-02': {'dateDebut': 1136160000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2006-01-01': {'dateDebut': 1136073600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2005',
#    'versions': {'2005-12-31': {'dateDebut': 1135987200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-12-16': {'dateDebut': 1134691200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-12-01': {'dateDebut': 1133395200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-11-15': {'dateDebut': 1132012800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-11-01': {'dateDebut': 1130803200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-09-28': {'dateDebut': 1127865600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-09-21': {'dateDebut': 1127260800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-09-09': {'dateDebut': 1126224000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-09-05': {'dateDebut': 1125878400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-08-25': {'dateDebut': 1124928000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-08-03': {'dateDebut': 1123027200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-07-29': {'dateDebut': 1122595200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-07-28': {'dateDebut': 1122508800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-07-27': {'dateDebut': 1122422400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-07-21': {'dateDebut': 1121904000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-06-30': {'dateDebut': 1120089600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-05-07': {'dateDebut': 1115424000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-04-01': {'dateDebut': 1112313600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-02-25': {'dateDebut': 1109289600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-01-19': {'dateDebut': 1106092800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2005-01-01': {'dateDebut': 1104537600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2004',
#    'versions': {'2004-12-31': {'dateDebut': 1104451200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-12-10': {'dateDebut': 1102636800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-11-16': {'dateDebut': 1100563200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-10-22': {'dateDebut': 1098403200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-10-01': {'dateDebut': 1096588800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-09-04': {'dateDebut': 1094256000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-08-21': {'dateDebut': 1093046400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-08-11': {'dateDebut': 1092182400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-08-07': {'dateDebut': 1091836800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-07-24': {'dateDebut': 1090627200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-07-10': {'dateDebut': 1089417600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-06-26': {'dateDebut': 1088208000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-06-22': {'dateDebut': 1087862400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-06-19': {'dateDebut': 1087603200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-06-05': {'dateDebut': 1086393600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-04-17': {'dateDebut': 1082160000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-03-27': {'dateDebut': 1080345600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-02-13': {'dateDebut': 1076630400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2004-02-12': {'dateDebut': 1076544000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2003',
#    'versions': {'2003-12-31': {'dateDebut': 1072828800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2003-08-22': {'dateDebut': 1061510400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2003-08-05': {'dateDebut': 1060041600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2003-08-03': {'dateDebut': 1059868800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2003-08-02': {'dateDebut': 1059782400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2003-01-04': {'dateDebut': 1041638400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2002',
#    'versions': {'2002-12-31': {'dateDebut': 1041292800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2002-12-12': {'dateDebut': 1039651200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2002-10-30': {'dateDebut': 1035936000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2002-07-01': {'dateDebut': 1025481600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2002-01-01': {'dateDebut': 1009843200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2001',
#    'versions': {'2001-12-29': {'dateDebut': 1009584000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-12-12': {'dateDebut': 1008115200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-11-16': {'dateDebut': 1005868800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-08-31': {'dateDebut': 999216000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-07-18': {'dateDebut': 995414400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-07-11': {'dateDebut': 994809600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-05-16': {'dateDebut': 989971200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-04-22': {'dateDebut': 987897600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-02-20': {'dateDebut': 982627200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2001-01-01': {'dateDebut': 978307200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False}],
#  'datePublication': '2999-01-01T00:00:00.000+0000'}

# %% [markdown]
# #### 2.9.3 - Data pipeline 1: Data Print

# %%
from datetime import datetime as dt
# Data cleaning
annee_recherchee = "2023"
resultat = ""

# Vérifier la présence du champ 'regroupements' et l’analyser
for group_1 in data_json_2_2_3['regroupements']:  # Parcours regroupement d'années : list de dictionnaires
    if group_1['title'] == annee_recherchee:  # Filtre pour l'année recherchée
        print(f"Année : {group_1['title']}")
        #resultat = resultat+ group_1['title'] + "n"

        # Parcours de chaque version de texte pour l'année courante
        for version_date, version_data in group_1['versions'].items():
            # Convertir le timestamp en une date lisible
            date_debut = dt.fromtimestamp(version_data['dateDebut'] / 1000).strftime('%Y-%m-%d')

            print(f"  Version du {version_date}:")
            print(f"    Date de début cible entrée en vigueur: {date_debut}")
            print(f"    Est la dernière version : {'Oui' if version_data['isEndVersion'] else 'Non'}")

            # Affichage des articles modificateurs
            print("    Articles modificateurs :")
            for article_id, article_data in version_data['articlesModificateurs'].items():
                print(f"      - ID : {article_id}")
                print(f"        Titre : {article_data['title']}")
                print(f"        Nature : {article_data['nature']}")
                date_debut_cible = dt.fromtimestamp(article_data['dateDebutCible'] / 1000).strftime('%Y-%m-%d')
                print(f"        Date de début cible : {date_debut_cible}")

                # Affichage des actions et des parents si disponibles
                if 'actions' in article_data:
                    for action_type, action_details in article_data['actions'].items():
                        print(f"        Action : {action_type}")

                        if 'parents' in action_details:
                            print("        Parents :")
                            for parent_id, parent_data in action_details['parents'].items():
                                print(f"          - ID parent  : {parent_id}")
                                print(f"            Nom parent : {parent_data['name']}")
                                print(f"            CID parent : {parent_data['cid']}")
                                if 'articlesCibles' in parent_data:
                                    print("            Articles cibles :")
                                    for cible_id, cible_data in parent_data['articlesCibles'].items():
                                        print(f"              - ID :{cible_id} - Article N° {cible_data['name']}")
                                        print(f"                    Date de début : {dt.fromtimestamp(cible_data['dateDebut'] / 1000).strftime('%Y-%m-%d')}")
                                        print(f"                    Date de fin : {dt.fromtimestamp(cible_data['dateFin'] / 1000).strftime('%Y-%m-%d')}")
# Out:
# Année : 2023
#   Version du 2023-12-31:
#     Date de début cible entrée en vigueur: 2023-12-31
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-12-30:
#     Date de début cible entrée en vigueur: 2023-12-30
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-12-08:
#     Date de début cible entrée en vigueur: 2023-12-08
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-12-01:
#     Date de début cible entrée en vigueur: 2023-12-01
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-10-26:
#     Date de début cible entrée en vigueur: 2023-10-26
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-10-25:
#     Date de début cible entrée en vigueur: 2023-10-25
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-10-15:
#     Date de début cible entrée en vigueur: 2023-10-15
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-10-01:
#     Date de début cible entrée en vigueur: 2023-10-01
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-09-01:
#     Date de début cible entrée en vigueur: 2023-09-01
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-07-22:
#     Date de début cible entrée en vigueur: 2023-07-22
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-07-20:
#     Date de début cible entrée en vigueur: 2023-07-20
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-07-17:
#     Date de début cible entrée en vigueur: 2023-07-17
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-07-15:
#     Date de début cible entrée en vigueur: 2023-07-15
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-06-11:
#     Date de début cible entrée en vigueur: 2023-06-11
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-06-03:
#     Date de début cible entrée en vigueur: 2023-06-03
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-05-26:
#     Date de début cible entrée en vigueur: 2023-05-26
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-05-17:
#     Date de début cible entrée en vigueur: 2023-05-17
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-05-07:
#     Date de début cible entrée en vigueur: 2023-05-07
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-03-11:
#     Date de début cible entrée en vigueur: 2023-03-11
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-02-23:
#     Date de début cible entrée en vigueur: 2023-02-23
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-02-19:
#     Date de début cible entrée en vigueur: 2023-02-19
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-02-06:
#     Date de début cible entrée en vigueur: 2023-02-06
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-02-01:
#     Date de début cible entrée en vigueur: 2023-02-01
#     Est la dernière version : Non
#     Articles modificateurs :
#   Version du 2023-01-01:
#     Date de début cible entrée en vigueur: 2023-01-01
#     Est la dernière version : Non
#     Articles modificateurs :

# %% [markdown]
# #### 2.9.4 - Data pipeline 2: To pd.DataFrame

# %%
from datetime import datetime

def convert_timestamp(timestamp):
    """
    Convertit un timestamp en millisecondes en une date lisible (YYYY-MM-DD).
    """
    if timestamp is None:
        return None
    return datetime.utcfromtimestamp(timestamp / 1000).strftime('%Y-%m-%d')

# %%
import pandas as pd
def transform_json_to_dataframe(data):
    """
    Transforme le JSON en DataFrame structuré avec les colonnes demandées.
    """
    rows = []

    for regroupement in data["regroupements"]:
        year = regroupement["title"]
        for version, version_data in regroupement["versions"].items():
            date_debut_version = convert_timestamp(version_data.get("dateDebut"))
            is_last_version = version_data.get("isEndVersion", False)
            articles_modificateurs = version_data.get("articlesModificateurs", {})

            for article_id, article_data in articles_modificateurs.items():
                title_article = article_data.get("title")
                nature_article = article_data.get("nature")
                date_debut_cible_article = convert_timestamp(article_data.get("dateDebutCible"))
                actions = article_data.get("actions", {})

                for action_type, action_data in actions.items():
                    parents = action_data.get("parents", {})
                    for parent_id, parent_data in parents.items():
                        parent_name = parent_data.get("name")
                        parent_cid = parent_data.get("cid")
                        articles_cibles = parent_data.get("articlesCibles", {})

                        for article_cible_id, article_cible_data in articles_cibles.items():
                            article_cible_name = article_cible_data.get("name")
                            article_cible_date_debut = convert_timestamp(article_cible_data.get("dateDebut"))
                            article_cible_date_fin = convert_timestamp(article_cible_data.get("dateFin"))

                            # Ajouter une ligne au tableau
                            rows.append({
                                "Année": year,
                                "Version du": version,
                                "Date de début cible d'entrée en vigueur": date_debut_version,
                                "Est la dernière version": is_last_version,
                                "ID Article Modificateur": article_id,
                                "Titre Article Modificateur": title_article,
                                "Nature Article Modificateur": nature_article,
                                "Date de début cible Article Modificateur": date_debut_cible_article,
                                "Action Article Modificateur": action_type,
                                "ID Parent": parent_id,
                                "Nom Parent": parent_name,
                                "CID Parent": parent_cid,
                                "ID Article Cible": article_cible_id,
                                "Titre Article Cible": article_cible_name,
                                "Date de début (Article Cible)": article_cible_date_debut,
                                "Date de fin (Article Cible)": article_cible_date_fin
                            })

    return pd.DataFrame(rows)

# %%
df_2_2_3 = transform_json_to_dataframe(data_json_2_2_3)

# %%
def pandas_to_excel(df):
  df.to_excel('data_output_ipynb/output.xlsx')
  return

# %%
pandas_to_excel(df_2_2_3)

# %% [markdown]
# # 3 - Concatenating all

# %% [markdown]
# Adding new columns by applying function 1 & 2

# %%
df_2_2_3.columns
# Out:
# Index(['Année', 'Version du', 'Date de début cible d'entrée en vigueur',
#        'Est la dernière version', 'ID Article Modificateur',
#        'Titre Article Modificateur', 'Nature Article Modificateur',
#        'Date de début cible Article Modificateur',
#        'Action Article Modificateur', 'ID Parent', 'Nom Parent', 'CID Parent',
#        'ID Article Cible', 'Titre Article Cible',
#        'Date de début (Article Cible)', 'Date de fin (Article Cible)'],
#       dtype='object')

# %%
# STEP 1: add column 1 content of new version of articles 
# Temps d'attente important envir 10 min 

df_2_2_3['Contenu_Nouv_Vers_Article'] = df_2_2_3.apply( lambda x: getArticle(x['ID Article Cible']), axis=1)

# %%
# STEP 2: add column 2 content of old version of articles
# Temps d'attente important envir 20 min 

df_2_2_3['Contenu_Ancien_Article'] = df_2_2_3.apply( lambda x: getArticle_prev_vers(x['ID Article Cible']), axis=1)

# %%
# STEP 3: add column 3 comparing old vs new version :
df_2_2_3['Compare contenu evo'] = df_2_2_3.apply(
    lambda row: "Contenu Similaire" if row['Contenu_Nouv_Vers_Article'] == row['Contenu_Ancien_Article'] else "OK change",
    axis=1
)

# %%
# Final result : exporting to excel 
pandas_to_excel(df_2_2_3)
